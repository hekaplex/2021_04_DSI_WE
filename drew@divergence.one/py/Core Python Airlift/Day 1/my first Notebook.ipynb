# %% [markdown]
# ## My Notebook

# %%
 6*"47"*17
# Out:
# '474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747474747'

# %%
txt = input("what string?")
repeat = int(input("how many times?"))
print(txt*repeat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8bb6dc916a47> in <module>
# ----> 1 txt = input("what string?")
#       2 repeat = int(input("how many times?"))
#       3 print(txt*repeat)
#
# ~\anaconda3\envs\hekahedron\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\envs\hekahedron\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
name = "Bob"
age = 40
name + str(age)
# Out:
# 'Bob40'

# %%
subtotal = 74.95
tax = subtotal * 0.0825
tax
# Out:
# 6.183375000000001

# %%
subtotal + tax
# Out:
# 81.133375

# %%
print(type(subtotal))
print(type(tax))
# Out:
# <class 'float'>
# <class 'float'>

# %%
print('a\tb\nc\td\n\"e\\')
# Out:
# a	b
# c	d
# "e\

# %%
children =["Andrew","Laura","Joe"]
print("kids: ",children, sep="~", end ="\n")
print("kids: "," ".join(children), sep="~", end ="\n")
print("kids_alpha:" ,children[0],children[2],children[1])
print("kids_alpha: A{0} B{1} C{2}".format(children[0],children[2],children[1]))
# Out:
# kids: ~['Andrew', 'Laura', 'Joe']
# kids: ~Andrew Laura Joe
# kids_alpha: Andrew Joe Laura
# kids_alpha: AAndrew BJoe CLaura

# %%
#function basics
#function name - print - def print...
#function takes one parameter "Hello World"
Hello = "bacon"
World = "potato"
print(Hello)
print(World)
print('Hello World')
var1 = "Hello 2021_02_CCT_WE!!!"
print(var1)
# Out:
# bacon
# potato
# Hello World
# Hello 2021_02_CCT_WE!!!

# %%
number = 4
print(type(number))
number = str(4)
type(number)
# Out:
# <class 'int'>
# str

# %%
futureValue = 0.0
type(futureValue)
# Out:
# float

# %%
#children Andrew Laura Joe 
children = "Andrew Laura Joe"

# %%
children =["Andrew","Laura","Joe"]
type(children)
# Out:
# list

# %%
children[2]
# Out:
# 'Joe'

# %%
months = 3
#Python is a zero-index language
rm = range(3)
type(rm)
# Out:
# range

# %%
#for i in range(3)
#iterator
for i in rm:
    print(i)
# Out:
# 0
# 1
# 2

# %%
#function definition, name and input parameters - no data types!!!
def calculateFutureValue(monthlyInvestment, monthlyRate, months):
#'''takes numbers and gives estimates'''    
# iterator for length of calculation cycle
    futureValue = 0.0
    for i in range(months):
#business logic
        futureValue = (
                futureValue
                + monthlyInvestment
            ) \
            * \
            ( \
                1 
                + monthlyRate
            )
#output of function
    return futureValue

monthlyInvestment = input("Configure Monthly Investment:\t")
monthlyRate = input("Configure Monthly Rate:\t")
months = input("Configure Months of investment:\t")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-9245271acedb> in <module>
#      18     return futureValue
#      19
# ---> 20 monthlyInvestment = input("Configure Monthly Investment:\t")
#      21 monthlyRate = input("Configure Monthly Rate:\t")
#      22 months = input("Configure Months of investment:\t")
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
calculateFutureValue(5000,.07,3)
# Out:
# 2
# 17199.715

# %%
type(Hello)
# Out:
# str

# %%
# !python --version
# Out:
# Python 3.8.5

# %%
print "Hello World"
# Out:
#   File "<ipython-input-4-2e860ebf713e>", line 1
#     print "Hello World"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello World")?

# %%
SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello World")?
TypeError: unsupported operand type(s) for +: 'float' and 'str'
ModuleNotFoundError: No module named 'tensorflow'
NameError: name 'Hello' is not defined
AttributeError: 'list' object has no attribute 'upper'

# %%
print("Hello World")
# Out:
# Hello World

# %%
#EOL = End of Line

# %%
counter = 0
score_total = 0
test_score = 0
# != is "Not Equal To"
#while nobody enters 999(quit msg)
while test_score != 999:
#convert text input to integer
    test_score = int(input("Enter test score: "))
#check for valid range 
    if test_score >= 0 and test_score <= 100:
#       score_total = score_total + test_score
        score_total += test_score # add new score to sum of old scores
        counter += 1 # add another counter increment
#give graceful warning
    else:
        print("use numbers between 0 and 100")
#calculate average
average_score = round(score_total / counter)
#give feedback                
print("Total Score: " + str(score_total))
print("Average Score: " + str(average_score))
print("Number of Scores: " + str(counter))
# Out:
# Enter test score: 999
# use numbers between 0 and 100
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-90-149c6e9c7427> in <module>
#      16         print("use numbers between 0 and 100")
#      17 #calculate average
# ---> 18 average_score = round(score_total / counter)
#      19 #give feedback
#      20 print("Total Score: " + str(score_total))
#
# ZeroDivisionError: division by zero

# %%
calculateFutureValue?

# %%
children
# Out:
# ['Andrew', 'Laura', 'Joe']

# %%
print(children)
# Out:
# ['Andrew', 'Laura', 'Joe']

# %%
junk = [ 4, "boing", 3.6]

# %%
print(junk)
# Out:
# [4, 'boing', 3.6]

# %%
a = str()
for i in junk:
    a+=str(i)+" "
print(a)
# Out:
# 4 boing 3.6

# %%
print(children[0],children[1],children[2])
# Out:
# Andrew Laura Joe

# %%
a = str()
for i in children:
    a+=str(i)+" "
print(a)
# Out:
# Andrew Laura Joe

# %%
print(children[0],children[1],children[2],sep="\n",end="!!!")
# Out:
# Andrew
# Laura
# Joe!!!

# %%
print(children[0],children[1],children[2],sep=str(junk),end="!!!")
# Out:
# Andrew[4, 'boing', 3.6]Laura[4, 'boing', 3.6]Joe!!!

# %%
newlist = [1,2,3,4]

# %%
print(newlist)
# Out:
# [1, 2, 3, 4]

# %%
print("What is your first name?")
first_name = input()
# Out:
# What is your first name?
# Drew

# %%
print("Hello, " + first_name + "!")
# Out:
# Hello, Drew!

# %%
>>> (min_age == 47)
True
>>> (min_age == 47) and (age == 40)
True
>>> not(active)
True
>>> (min_age == 47) and not(age == 40)
False
>>> (min_age == 47) and not(age == 47)
True
>>> (min_age == 47) and not(age == 47) or (age != min_age)
True
>>> ((min_age == 47) and not(age == 47)) or (age != min_age)
True
>>>

# %%
print(children)
# Out:
# ['Andrew', 'Laura', 'Joe']

# %%
child2 = str(children)
print(child2)
print(child2.lower())
print(child2.upper())
# Out:
# ['Andrew', 'Laura', 'Joe']
# ['andrew', 'laura', 'joe']
# ['ANDREW', 'LAURA', 'JOE']

# %%
type(child2)
# Out:
# str

# %%
children.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-5e508e58a6f9> in <module>
# ----> 1 children.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
#!/usr/bin/env python3

#function defintion and input parameters
def calculateFutureValue(monthlyInvestment, monthlyRate, months):
# iterator for length of calculation cycle
    futureValue = 0.0
    for i in range(months):
#business logic
        futureValue = (
                futureValue
                + monthlyInvestment
            ) \
            * \
            ( \
                1 
                + monthlyRate/100
            )
#output of function
    return str(round(futureValue,2))

# display a welcome message
print("Welcome to the Future Value Calculator")
print()

# get input from the user
monthlyInvestment = float(input("Configure Monthly Investment:\t"))
monthlyRate = float(input("Configure Monthly Rate:\t"))
ham = float(input("Configure Years of investment:\t"))

def ytm(years):
    return int(round(years*12,0))

#calculate final value
final_value = str(calculateFutureValue(monthlyInvestment, monthlyRate, ytm(ham)))

# display the results
print("final value: $"+final_value)
# Out:
# Welcome to the Future Value Calculator
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-c8494eaa6afa> in <module>
#      24
#      25 # get input from the user
# ---> 26 monthlyInvestment = float(input("Configure Monthly Investment:\t"))
#      27 monthlyRate = float(input("Configure Monthly Rate:\t"))
#      28 ham = float(input("Configure Years of investment:\t"))
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
vart = range(0,100,7)
for i in vart: 
    print (i)
# Out:
# 0
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98
