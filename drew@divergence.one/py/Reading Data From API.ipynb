# %% [markdown]
# # Lesson 7: Advanced Web Scraping and Data Gathering
# ## Topic 3: Reading data from an API
# This Notebook shows how to use a free API (no authorization or API key needed) to download some basic information about various countries around the world and put them in a DataFrame.

# %% [markdown]
# ### Import libraries

# %%
import urllib.request, urllib.parse
from urllib.error import HTTPError,URLError
import pandas as pd

# %% [markdown]
# ### Exercise 20: Define the base URL

# %%
serviceurl = 'https://restcountries.eu/rest/v2/name/'

# %% [markdown]
# ### Exercise 21: Define a function to pull the country data from the API

# %%
def get_country_data(country):
    """
    Function to get data about a country from "https://restcountries.eu" API
    """
    country_name=str(country)
    url = serviceurl + country_name
    
    try: 
        uh = urllib.request.urlopen(url)
    except HTTPError as e:
        print("Sorry! Could not retrive anything on {}".format(country_name))
        return None
    except URLError as e:
        print('Failed to reach a server.')
        print('Reason: ', e.reason)
        return None
    else:
        data = uh.read().decode()
        print("Retrieved data on {}. Total {} characters read.".format(country_name,len(data)))
        return data

# %% [markdown]
# ### Exercise 22: Test the function by passing a correct and an incorrect argument

# %%
country_name = 'Switzerland'

# %%
data=get_country_data(country_name)
# Out:
# Retrieved data on Switzerland. Total 1090 characters read.

# %%
country_name1 = 'Switzerland1'

# %%
data1=get_country_data(country_name1)
# Out:
# Sorry! Could not retrive anything on Switzerland1

# %%
data
# Out:
# '[{"name":"Switzerland","topLevelDomain":[".ch"],"alpha2Code":"CH","alpha3Code":"CHE","callingCodes":["41"],"capital":"Bern","altSpellings":["CH","Swiss Confederation","Schweiz","Suisse","Svizzera","Svizra"],"region":"Europe","subregion":"Western Europe","population":8341600,"latlng":[47.0,8.0],"demonym":"Swiss","area":41284.0,"gini":33.7,"timezones":["UTC+01:00"],"borders":["AUT","FRA","ITA","LIE","DEU"],"nativeName":"Schweiz","numericCode":"756","currencies":[{"code":"CHF","name":"Swiss franc","symbol":"Fr"}],"languages":[{"iso639_1":"de","iso639_2":"deu","name":"German","nativeName":"Deutsch"},{"iso639_1":"fr","iso639_2":"fra","name":"French","nativeName":"français"},{"iso639_1":"it","iso639_2":"ita","name":"Italian","nativeName":"Italiano"}],"translations":{"de":"Schweiz","es":"Suiza","fr":"Suisse","ja":"スイス","it":"Svizzera","br":"Suíça","pt":"Suíça","nl":"Zwitserland","hr":"Švicarska","fa":"سوئیس"},"flag":"https://restcountries.eu/data/che.svg","regionalBlocs":[{"acronym":"EFTA","name":"European Free Trade Association","otherAcronyms":[],"otherNames":[]}],"cioc":"SUI"}]'

# %% [markdown]
# ### Exercise 23: Use the built-in `JSON` library to read and examine the data properly

# %%
import json

# %%
# Load from string 'data'
x=json.loads(data)

# %%
# Load the only element
y=x[0]

# %%
type(y)
# Out:
# dict

# %%
y.keys()
# Out:
# dict_keys(['name', 'topLevelDomain', 'alpha2Code', 'alpha3Code', 'callingCodes', 'capital', 'altSpellings', 'region', 'subregion', 'population', 'latlng', 'demonym', 'area', 'gini', 'timezones', 'borders', 'nativeName', 'numericCode', 'currencies', 'languages', 'translations', 'flag', 'regionalBlocs', 'cioc'])

# %% [markdown]
# ### Exercise 24: Can you print all the data elements one by one?

# %%
for k,v in y.items():
    print("{}: {}".format(k,v))
# Out:
# name: Switzerland
# topLevelDomain: ['.ch']
# alpha2Code: CH
# alpha3Code: CHE
# callingCodes: ['41']
# capital: Bern
# altSpellings: ['CH', 'Swiss Confederation', 'Schweiz', 'Suisse', 'Svizzera', 'Svizra']
# region: Europe
# subregion: Western Europe
# population: 8341600
# latlng: [47.0, 8.0]
# demonym: Swiss
# area: 41284.0
# gini: 33.7
# timezones: ['UTC+01:00']
# borders: ['AUT', 'FRA', 'ITA', 'LIE', 'DEU']
# nativeName: Schweiz
# numericCode: 756
# currencies: [{'code': 'CHF', 'name': 'Swiss franc', 'symbol': 'Fr'}]
# languages: [{'iso639_1': 'de', 'iso639_2': 'deu', 'name': 'German', 'nativeName': 'Deutsch'}, {'iso639_1': 'fr', 'iso639_2': 'fra', 'name': 'French', 'nativeName': 'français'}, {'iso639_1': 'it', 'iso639_2': 'ita', 'name': 'Italian', 'nativeName': 'Italiano'}]
# translations: {'de': 'Schweiz', 'es': 'Suiza', 'fr': 'Suisse', 'ja': 'スイス', 'it': 'Svizzera', 'br': 'Suíça', 'pt': 'Suíça', 'nl': 'Zwitserland', 'hr': 'Švicarska', 'fa': 'سوئیس'}
# flag: https://restcountries.eu/data/che.svg
# regionalBlocs: [{'acronym': 'EFTA', 'name': 'European Free Trade Association', 'otherAcronyms': [], 'otherNames': []}]
# cioc: SUI

# %% [markdown]
# ### Exercise 25: The dictionary values are not of the same type - print all the languages spoken

# %%
for lang in y['languages']:
    print(lang['nativeName'])
# Out:
# Deutsch
# français
# Italiano

# %% [markdown]
# ### Exercise 26: Write a function which can take a list of countries and return a DataFrame containing key info
# * Capital
# * Region
# * Sub-region
# * Population
# * lattitude/longitude
# * Area
# * Gini index
# * Timezones
# * Currencies
# * Languages

# %%
import pandas as pd
import json
def build_country_database(list_country):
    """
    Takes a list of country names.
    Output a DataFrame with key information about those countries.
    """
    # Define an empty dictionary with keys
    country_dict={'Country':[],'Capital':[],'Region':[],'Sub-region':[],'Population':[],
                  'Lattitude':[],'Longitude':[],'Area':[],'Gini':[],'Timezones':[],
                  'Currencies':[],'Languages':[]}
    
    for c in list_country:
        data = get_country_data(c)
        if data!=None:
            x = json.loads(data)
            y=x[0]
            country_dict['Country'].append(y['name'])
            country_dict['Capital'].append(y['capital'])
            country_dict['Region'].append(y['region'])
            country_dict['Sub-region'].append(y['subregion'])
            country_dict['Population'].append(y['population'])
            country_dict['Lattitude'].append(y['latlng'][0])
            country_dict['Longitude'].append(y['latlng'][1])
            country_dict['Area'].append(y['area'])
            country_dict['Gini'].append(y['gini'])
            # Note the code to handle possibility of multiple timezones as a list
            if len(y['timezones'])>1:
                country_dict['Timezones'].append(','.join(y['timezones']))
            else:
                country_dict['Timezones'].append(y['timezones'][0])
            # Note the code to handle possibility of multiple currencies as dictionaries
            if len(y['currencies'])>1:
                lst_currencies = []
                for i in y['currencies']:
                    lst_currencies.append(i['name'])
                country_dict['Currencies'].append(','.join(lst_currencies))
            else:
                country_dict['Currencies'].append(y['currencies'][0]['name'])
            # Note the code to handle possibility of multiple languages as dictionaries
            if len(y['languages'])>1:
                lst_languages = []
                for i in y['languages']:
                    lst_languages.append(i['name'])
                country_dict['Languages'].append(','.join(lst_languages))
            else:
                country_dict['Languages'].append(y['languages'][0]['name'])
    
    # Return as a Pandas DataFrame
    return pd.DataFrame(country_dict)

# %% [markdown]
# ### Exercise 27: Test the function by building a small database of countries' info. Include an incorrect name too.

# %%
df1=build_country_database(['Nigeria','Switzerland','France',
                            'Turmeric','Russia','Kenya','Singapore'])
# Out:
# Sorry! Could not retrive anything on Nigeria
# Retrieved data on Switzerland. Total 1090 characters read.
# Retrieved data on France. Total 1047 characters read.
# Sorry! Could not retrive anything on Turmeric
# Retrieved data on Russia. Total 1120 characters read.
# Retrieved data on Kenya. Total 1052 characters read.
# Retrieved data on Singapore. Total 1223 characters read.

# %%
df1
# Out:
#               Country    Capital  Region          Sub-region  Population  \
# 0         Switzerland       Bern  Europe      Western Europe     8341600
# 1              France      Paris  Europe      Western Europe    66710000
# 2  Russian Federation     Moscow  Europe      Eastern Europe   146599183
# 3               Kenya    Nairobi  Africa      Eastern Africa    47251000
# 4           Singapore  Singapore    Asia  South-Eastern Asia     5535000
#
#    Lattitude  Longitude        Area  Gini  \
# 0  47.000000        8.0     41284.0  33.7
# 1  46.000000        2.0    640679.0  32.7
# 2  60.000000      100.0  17124442.0  40.1
# 3   1.000000       38.0    580367.0  47.7
# 4   1.366667      103.8       710.0  48.1
#
#                                            Timezones  \
# 0                                          UTC+01:00
# 1  UTC-10:00,UTC-09:30,UTC-09:00,UTC-08:00,UTC-04...
# 2  UTC+03:00,UTC+04:00,UTC+06:00,UTC+07:00,UTC+08...
# 3                                          UTC+03:00
# 4                                          UTC+08:00
#
#                        Currencies                    Languages
# 0                     Swiss franc        German,French,Italian
# 1                            Euro                       French
# 2                   Russian ruble                      Russian
# 3                 Kenyan shilling              English,Swahili
# 4  Brunei dollar,Singapore dollar  English,Malay,Tamil,Chinese

# %%
x=json.loads?

# %%
x=json.loads

# %%
setx?

# %%
#column digging
keys = []
data_tmp = []
with open("C:\\Users\\andre\\Downloads\\All_Beauty.json", "r") as file:
        for line in file:
            line = line.replace("\n", "")
            tmp = json.loads(line)
            data_tmp.append(tmp)
            for k in list(tmp.keys()):
                keys.append(k)

# %%
data_tmp
# Out:
# [{'overall': 1.0,
#   'verified': True,
#   'reviewTime': '02 19, 2015',
#   'reviewerID': 'A1V6B6TNIC10QE',
#   'asin': '0143026860',
#   'reviewerName': 'theodore j bigham',
#   'reviewText': 'great',
#   'summary': 'One Star',
#   'unixReviewTime': 1424304000},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '12 18, 2014',
#   'reviewerID': 'A2F5GHSXFQ0W6J',
#   'asin': '0143026860',
#   'reviewerName': 'Mary K. Byke',
#   'reviewText': "My  husband wanted to reading about the Negro Baseball and this a great addition to his library\n Our library doesn't haveinformation so this book is his start. Tthank you",
#   'summary': "... to reading about the Negro Baseball and this a great addition to his library Our library doesn't haveinformation so ...",
#   'unixReviewTime': 1418860800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '08 10, 2014',
#   'reviewerID': 'A1572GUYS7DGSR',
#   'asin': '0143026860',
#   'reviewerName': 'David G',
#   'reviewText': 'This book was very informative, covering all aspects of game.',
#   'summary': 'Worth the Read',
#   'unixReviewTime': 1407628800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 11, 2013',
#   'reviewerID': 'A1PSGLFK1NSVO',
#   'asin': '0143026860',
#   'reviewerName': 'TamB',
#   'reviewText': 'I am already a baseball fan and knew a bit about the Negro leagues, but I learned a lot more reading this book.',
#   'summary': 'Good Read',
#   'unixReviewTime': 1362960000},
#  {'overall': 5.0,
#   'vote': '5',
#   'verified': True,
#   'reviewTime': '12 25, 2011',
#   'reviewerID': 'A6IKXKZMTKGSC',
#   'asin': '0143026860',
#   'reviewerName': 'shoecanary',
#   'reviewText': "This was a good story of the Black leagues. I bought the book to teach in my high school reading class. I found it very informative and exciting. I would recommend to anyone interested in the history of the black leagues. It is well written, unlike a book of facts. The McKissack's continue to write good books for young audiences that can also be enjoyed by adults!",
#   'summary': 'More than facts, a good story read!',
#   'unixReviewTime': 1324771200},
#  {'overall': 5.0,
#   'vote': '4',
#   'verified': False,
#   'reviewTime': '02 26, 2010',
#   'reviewerID': 'A36NF437WZLQ9E',
#   'asin': '0143026860',
#   'reviewerName': 'W. Powell',
#   'reviewText': 'Today I gave a book about the Negro Leagues of Baseball to a traveling friend. Its a book I\'ve read more than once and felt that my friend would truly enjoy. It felt like giving a gift that you wanted to keep for yourself. I parted with the book knowing that my friend would enjoy reading it on his journey back east. Before giving him the book I spent about thirty minutes flipping through its pages and saying goodbye to some of the stories in it. I know I\'ll come across the book again, but for me, parting with books is like wishing a friend well on a journey, just as this friend of mine was journeying. Its great to send a visiting friend off with a friendly gift.\n\nWell, in leafing through the book\'s pages I came across a few paragraphs I wanted to retain as a memory of my friend the book. Here below are the book and the lines from it that show in words what the negro baseball players faced every day of their lives; a color barrier that prevented them from gaining national sports recognition as professionals of the game they loved so much, baseball. Though Negro men had proven themselves heroic, capable of soldiering bravely in foreign battles of World War II, America was still treating them as second class citizens or less here at home. Major League Baseball would lead the nation in recovering from its racial prejudicial past. The nation today, even with a Black President, is still playing catch up.\n\nexcerpt from Black Diamond:  "Only one thing is keeping them out of the big leagues, and that is the pigmentation of their skin." Shirley Povich washington post',
#   'summary': 'The Gift of Black Baseball',
#   'unixReviewTime': 1267142400},
#  {'overall': 4.0,
#   'vote': '14',
#   'verified': False,
#   'reviewTime': '03 7, 2001',
#   'reviewerID': 'A10Q8NIFOVOHFV',
#   'asin': '0143026860',
#   'reviewerName': 'Robert S. Clay Jr.',
#   'reviewText': 'The story of race relations in American history is one of lost opportunity.  This concise history of the Negro Baseball Leagues for young adult readers illustrates this basic point.  The book discusses the names, dates, and circumstances of the major figures and events of the flip side of American baseball history. Legendary names such as Josh Gibson, "Cool Papa" Bell, and Satchel Page are just a few of the remarkable players who made important contributions to the game.  Among others, they played for teams with names such as The Homestead Grays, The St. Louis Stars, and The Kansas City Monarchs.  The book also tells the story of owners and managers, such names as Negro National League founder Rube Foster and the tough as nails woman owner of the Newark Eagles, Effa Manley spring to mind.  The book also briefly explains how the infamous Jim Crow tradition brought about the Negro Baseball saga.  In 1947, major league baseball was sucessfully integrated and that spelled the doom of the Negro Baseball leagues.  The text includes an ample number of photographs.  To assist younger readers, and for easy reference purposes, a player profile and time line section is provided at the back of the book.  Underlying the historical text, there is the theme that segregated baseball mirrored the nagging problem of racism in America.  A sense of fair play and even-handed justice demands that talent, skill, and just plain style should be celebrated, regardless of race.  To do otherwise cheats everybody of a rewarding experience.  Imagine if the great players of the Negro Baseball Leagues had the chance to play (with or against) the great players of the major leagues.  Consider the void created by lost opportunity.  ;-)',
#   'summary': 'Baseball, America, and racism.',
#   'unixReviewTime': 983923200},
#  {'overall': 1.0,
#   'verified': True,
#   'reviewTime': '04 10, 2017',
#   'reviewerID': 'A26PO1B2Q2G1CS',
#   'asin': '014789302X',
#   'reviewerName': 'Jacqueline Diaz',
#   'reviewText': "I didn't like this product it smudged all under my eyes throughly the day",
#   'summary': 'One Star',
#   'unixReviewTime': 1491782400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '01 3, 2017',
#   'reviewerID': 'AQ812VYVTC2RJ',
#   'asin': '014789302X',
#   'reviewerName': 'Khadijah Ali-Evans',
#   'reviewText': 'I simply love the product. I appreciate print feed back regarding my order',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1483401600},
#  {'overall': 1.0,
#   'vote': '3',
#   'verified': True,
#   'reviewTime': '11 19, 2016',
#   'reviewerID': 'AMACNEW14ADMX',
#   'asin': '014789302X',
#   'reviewerName': 'rabiyaa123',
#   'reviewText': 'it burns your eyes when u put it on  and very light so u have to keep going back n forth a lot to get the dark eyeliner color.\nalso it smudges lot. waste of money.',
#   'summary': 'i do not recommend.',
#   'unixReviewTime': 1479513600},
#  {'overall': 2.0,
#   'verified': True,
#   'reviewTime': '11 10, 2016',
#   'reviewerID': 'A5FS4FVWR77O6',
#   'asin': '014789302X',
#   'reviewerName': 'Lilly',
#   'reviewText': 'smaller versions, not full size as shown in pics',
#   'summary': 'Two Stars',
#   'unixReviewTime': 1478736000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 26, 2016',
#   'reviewerID': 'A1NLF2JD7BVOB4',
#   'asin': '014789302X',
#   'reviewerName': 'igzotikvet',
#   'reviewText': 'great eye liner.  good seller',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1474848000},
#  {'overall': 4.0,
#   'vote': '5',
#   'verified': True,
#   'reviewTime': '08 5, 2016',
#   'reviewerID': 'A3CKVF2ZR1CBO0',
#   'asin': '014789302X',
#   'reviewerName': 'M. Morretti',
#   'reviewText': "purchased for vending resale at bellydance weekend workshop. Nice quality, love the compact packaging, ingredient details are a bit sketchy but i haven't gone blind yet",
#   'summary': 'Nice quality, love the compact packaging',
#   'unixReviewTime': 1470355200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '07 29, 2016',
#   'reviewerID': 'A3IFT6SR16SAYU',
#   'asin': '014789302X',
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'I love it and it arrived on time',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1469750400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '06 18, 2016',
#   'reviewerID': 'A2BQ7NB90SBVIA',
#   'asin': '014789302X',
#   'reviewerName': 'Zury M.',
#   'reviewText': 'Really nice eyeliner!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1466208000},
#  {'overall': 5.0,
#   'vote': '5',
#   'verified': True,
#   'reviewTime': '05 25, 2016',
#   'reviewerID': 'A92AYWTA52KXE',
#   'asin': '014789302X',
#   'reviewerName': 'Shenia Morris',
#   'reviewText': 'It goes on very easily and makes my eyes look Bold and Beautiful',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1464134400},
#  {'overall': 5.0,
#   'vote': '2',
#   'verified': True,
#   'reviewTime': '03 26, 2016',
#   'reviewerID': 'AR6LNUWXJFYE6',
#   'asin': '014789302X',
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'Letz talk about DRAMA!!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1458950400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 1, 2015',
#   'reviewerID': 'A2V9BG2MDQVCYX',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'Alex G',
#   'reviewText': 'LOVE, LOVE, LOVE!! The movie was breathtaking and this book really shows you the behind-the-scenes work that was needed to make the gorgeous film. A must buy for any lover of the film or art in general.',
#   'summary': 'Gorgeous!',
#   'unixReviewTime': 1422748800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '01 30, 2015',
#   'reviewerID': 'AIL9Q82L1G2YO',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'TSENG TSUNG-CHIN',
#   'reviewText': 'Very good!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1422576000},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '12 1, 2014',
#   'reviewerID': 'A1ROGN2QPKZGP7',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'Nikolai G. J. Geier',
#   'reviewText': "Gorgeous insights on the making of this movie abound, though I must confess some disappointment at how little we see of two things: Story insights, and Aisling. I'm a little accustomed to getting a mix of art and emotion in my Art Of books, and this book feels like it focuses entirely on the art and leaves the story behind. I also would've liked to see more than one or two pages of Aisling illustrations.\n\nThat said, it's pretty much exactly how it's billed, and it's a really pretty (and really big) book that definitely showcases how gorgeous the movie was. If you want art, you get art.",
#   'summary': 'Mesmerizing Illustrations',
#   'unixReviewTime': 1417392000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '11 12, 2014',
#   'reviewerID': 'A141Z5WI6GVM6Y',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'DRD',
#   'reviewText': "Beautifully written and produced.  Even if you haven't seen the movie, it is a lovely book to page through.  You can study the art in detail and it also shows how a diverse group of  artists' worked together to create something unique and memorable that came out of one person's vision.",
#   'summary': 'Inspiring',
#   'unixReviewTime': 1415750400},
#  {'overall': 5.0,
#   'vote': '4',
#   'verified': True,
#   'reviewTime': '09 4, 2014',
#   'reviewerID': 'A1M3JNGXB8IU7I',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'Amy Byun',
#   'reviewText': "A beautiful book and a comprehensive one at that too! While some art books end up focusing on one aspect of it's respective movie, 'Desiging the Secret of Kells' explores not only how the creators painstakingly captured its beautiful art style, but also looks into character design, production process, story boarding and writing, and  much more. From the caption and footnotes in the book tells how much the creators are passionate about and love this masterpiece. Just flipping through this book was a joy. You have to read it to believe it. :>",
#   'summary': 'A must have for any art fanatics',
#   'unixReviewTime': 1409788800},
#  {'overall': 5.0,
#   'vote': '6',
#   'verified': False,
#   'reviewTime': '07 24, 2014',
#   'reviewerID': 'A3NYLVMP922AE5',
#   'asin': '0992916305',
#   'style': {'Format:': ' Hardcover'},
#   'reviewerName': 'G. Stapleton',
#   'reviewText': "I have waited and waited for this book and I finally got it. Not only did I get it, it was also signed as well as a pencil sketch done by the Producer and Creator. As I write this I am attending the 2014 San Diego Comic Con. I was so stoked. Anyway, the book not just discusses the film but is very transparent in detailing the process. Even down to giving the color codes of the characters like their eye lash color. Very cool and detailed. If you get your hands on one get it. This will be one that the resale value will remain solid. That's if you'd want to give up this classic gem.",
#   'summary': 'Waited so long.',
#   'unixReviewTime': 1406160000},
#  {'overall': 5.0,
#   'verified': False,
#   'reviewTime': '05 16, 2012',
#   'reviewerID': 'A1DN3KBTCYBH6K',
#   'asin': '1620213982',
#   'style': {'Size:': ' 44 oz'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'The product was cute and easy to use.  It arrived quickly and in perfect condition.  We used the wall decals on the window, wall and mirror.  Thank you',
#   'summary': 'cute!',
#   'unixReviewTime': 1337126400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 26, 2012',
#   'reviewerID': 'A1TA38LWZO0NZS',
#   'asin': '1620213982',
#   'style': {'Size:': ' 300'},
#   'reviewerName': 'deucez24',
#   'reviewText': 'Fun had by all.  Game night just got better.  Bingo with a twist, can be played for fun or friendly wager.',
#   'summary': 'Fun twist to the old favorite, Bingo.',
#   'unixReviewTime': 1330214400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '01 16, 2012',
#   'reviewerID': 'A2OZBC5SG575G1',
#   'asin': '1620213982',
#   'style': {'Size:': ' 3 pack'},
#   'reviewerName': 'Jean A.',
#   'reviewText': "You will love this card.  I'm going to use for Get Well, Birthdays... or Thank You's... or even to add on a gift.  I'll be ordering more for sure.  Very special cards everyone will like.",
#   'summary': 'ADORABLE Cards!',
#   'unixReviewTime': 1326672000},
#  {'overall': 5.0,
#   'vote': '5',
#   'verified': True,
#   'reviewTime': '11 24, 2011',
#   'reviewerID': 'A2YKYIA11M9XTX',
#   'asin': '1620213982',
#   'style': {'Size:': ' 3 pack'},
#   'reviewerName': 'Booklady',
#   'reviewText': 'Robert Sabuda\'s cards are always magical and this one could be a "smile in an envelope".  I send these as get well cards, and they never fail to get the most enthusiastic responses-- the last person I sent one to said, this is like getting a "smile in an envelope" -- Thanks for carrying these wonderful cards.  They will brighten any gloomy day and cheer up even the grumpiest patients!',
#   'summary': 'Send a smile to someone you love!',
#   'unixReviewTime': 1322092800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 29, 2011',
#   'reviewerID': 'A32MUH70JIV7TS',
#   'asin': '1620213982',
#   'style': {'Size:': ' 3'},
#   'reviewerName': 'sallyftw',
#   'reviewText': "I thought the previous reviewers were exaggerating a bit about the size of this charm but they were not.  It is literally the size of my phone.  It is a very nice charm though and it looks nice hanging out of my front pocket.  The metal cloud charm somehow fell off and is lost forever but I still have the rubbery one on my phone and its a nice thing to hold your phone with so overall I'm happy with this purchase and Naruto fans comment on it all the time =]",
#   'summary': 'HUUUUGE!',
#   'unixReviewTime': 1319846400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '08 27, 2011',
#   'reviewerID': 'A3S57667R6V4S4',
#   'asin': '1620213982',
#   'style': {'Size:': ' 45 Oz'},
#   'reviewerName': 'Patricia A. Hofer',
#   'reviewText': 'Item was bought as a Christmas gift.  This is the fourth in the series that I have bought for the person.\nShe loves Thomas Kinkade.  Will probably buy the others in this series if still available next year.',
#   'summary': 'Thomas Kinkade Angel of Glory Illuminated figurine',
#   'unixReviewTime': 1314403200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 29, 2011',
#   'reviewerID': 'A3JLEHAK528W8Z',
#   'asin': '1620213982',
#   'style': {'Size:': ' Color48'},
#   'reviewerName': 'remi',
#   'reviewText': 'This works great! A must for your pets and yourself when enjoying nature. Ticks are especially bad this year where I live and it has proven to be a wonderful addition to my outdoor gear.',
#   'summary': 'This is the perfect tick removal tool.',
#   'unixReviewTime': 1304035200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 31, 2010',
#   'reviewerID': 'A1XA71UE5A7F5B',
#   'asin': '1620213982',
#   'style': {'Size:': ' 3'},
#   'reviewerName': 'Eduardo Yanez',
#   'reviewText': "This Cell Phone Charm is way bigger than In the picture, which comes in handy when I'm walking around With my Cell Phone at Work.",
#   'summary': 'Akatsuki Pride',
#   'unixReviewTime': 1288483200},
#  {'overall': 5.0,
#   'vote': '2',
#   'verified': True,
#   'reviewTime': '09 14, 2010',
#   'reviewerID': 'A3BEXXPM77KR5Z',
#   'asin': '1620213982',
#   'style': {'Size:': ' 3'},
#   'reviewerName': 'prodoman6',
#   'reviewText': 'This product is great!! I nvr thought it would be as big as i thought but its just the right size for any type of phone.\nIts material is good so as it design\n\nI recommend getting 1 of these if ur a true naruto ship fan :D',
#   'summary': 'Great product',
#   'unixReviewTime': 1284422400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '05 8, 2018',
#   'reviewerID': 'A9KCT397IWK97',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Taylor Noble',
#   'reviewText': 'Wonderful stand for my brush and razor. Much better than just setting my razor and brush down on the bathroom sick. If you are thinking about getting it just do it. It is worth it.',
#   'summary': 'Wonderful stand for my brush and razor',
#   'unixReviewTime': 1525737600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '05 8, 2018',
#   'reviewerID': 'A36Z95ZFDMNL99',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'monica',
#   'reviewText': 'I bought this for my boyfriend and he absolutely loved it thanks for a great product',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1525737600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '05 6, 2018',
#   'reviewerID': 'AB6RYXLZSKHIR',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Victor J. Mazzella',
#   'reviewText': 'Looks nice,well made, hope to have it for many years.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1525564800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '05 3, 2018',
#   'reviewerID': 'A210V878QFZW9V',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'T',
#   'reviewText': "It's classy as all get out.",
#   'summary': 'Five Stars',
#   'unixReviewTime': 1525305600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '05 2, 2018',
#   'reviewerID': 'A18WMBY4BAB7ES',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Thor-Reader',
#   'reviewText': 'Nice stand.  Well polished.  Holds razor and brush very well',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1525219200},
#  {'overall': 2.0,
#   'verified': True,
#   'reviewTime': '05 1, 2018',
#   'reviewerID': 'A2667UCM2FYMQ5',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Jack',
#   'reviewText': 'The brush side was too small for my brush. But I bent it just a little and it fits fine now.',
#   'summary': 'But I bent it just a little and it fits fine now.',
#   'unixReviewTime': 1525132800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '04 28, 2018',
#   'reviewerID': 'AQ3IBZ523E9NP',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'mvportly',
#   'reviewText': 'Solid construction, good fit and finish.  The razor side just fits my razor.',
#   'summary': 'good fit and finish',
#   'unixReviewTime': 1524873600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 28, 2018',
#   'reviewerID': 'A2Q6ZCAOTIKW5A',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Mikhail Uddin',
#   'reviewText': 'Wonderful. Great price, solid built, esthetically appealing and mostly practical. Highly recommended!!!',
#   'summary': 'Excellent',
#   'unixReviewTime': 1524873600},
#  {'overall': 2.0,
#   'verified': True,
#   'reviewTime': '04 26, 2018',
#   'reviewerID': 'A2HJQ1TBXTHXFQ',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Bubbi',
#   'reviewText': 'Holder is wobbly and cannot be screwed unless you wish to remove the bottom padding that holds the razor/brush stand.\n\nLook around for a better stand where you can easily tighten the screws when it loosens.',
#   'summary': 'Very wobbly stand...',
#   'unixReviewTime': 1524700800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '04 26, 2018',
#   'reviewerID': 'A33JNJ0DGA6JRU',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'S. Savage',
#   'reviewText': "It keeps my razor and shaving brush off of the counter.  The stand weighs enough that it isn't easily toppled over or pushed around.",
#   'summary': 'Ideal for home defense!',
#   'unixReviewTime': 1524700800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 26, 2018',
#   'reviewerID': 'A1KF66E65YEALF',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'james anthony sr',
#   'reviewText': 'Very nice, would recommend that you purchase the perfecto shaving brush.  It fits perfect, my old brush did not',
#   'summary': 'Quality',
#   'unixReviewTime': 1524700800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 25, 2018',
#   'reviewerID': 'AYYITJTFJCA77',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Adrian Piazza',
#   'reviewText': 'Solid base for both brush and razor.',
#   'summary': 'Good value',
#   'unixReviewTime': 1524614400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 18, 2018',
#   'reviewerID': 'A35GAM2X7G7LAI',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'tg',
#   'reviewText': "Elegant design, well crafted and extremely functional.  It's beautiful enough to leave out on a bathroom vanity.  Very pleased.",
#   'summary': "It's beautiful enough to leave out on a bathroom vanity",
#   'unixReviewTime': 1524009600},
#  {'image': ['https://images-na.ssl-images-amazon.com/images/I/7188WL9FM5L._SY88.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/71LTtXSjChL._SY88.jpg'],
#   'overall': 2.0,
#   'verified': True,
#   'reviewTime': '04 17, 2018',
#   'reviewerID': 'A1Z8A548Z31SUB',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'X. Barnes',
#   'reviewText': 'Does not fit brush handle and razor slips easily off center.',
#   'summary': 'Should be better for the price',
#   'unixReviewTime': 1523923200},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '04 17, 2018',
#   'reviewerID': 'A2XBDWQ3Z8GZM',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Rebecca Curtis',
#   'reviewText': 'Works great.',
#   'summary': 'Four Stars',
#   'unixReviewTime': 1523923200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 16, 2018',
#   'reviewerID': 'A2FT0AFHQ32G33',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Nichole',
#   'reviewText': 'The grip is very nice.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1523836800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 14, 2018',
#   'reviewerID': 'AIVFUM7JDR4KM',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Bodyguard4U',
#   'reviewText': 'Built well and nice finish. Only fits smaller handle brushes.',
#   'summary': 'Sturdy stand worth having',
#   'unixReviewTime': 1523664000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 12, 2018',
#   'reviewerID': 'A12GV837WV9DA2',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Peter breuer',
#   'reviewText': 'Great product. Well made and stable. Provides my brush a great place to dry properly. Stylish appearance as well.',
#   'summary': 'Great product. Well made and stable',
#   'unixReviewTime': 1523491200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 12, 2018',
#   'reviewerID': 'A14BXZB8SZCCY1',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Carl M Froess',
#   'reviewText': 'Exactly as described.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1523491200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 12, 2018',
#   'reviewerID': 'A37P4JQKJQ6ICE',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Nicki Raymond',
#   'reviewText': 'was a gift and loves it!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1523491200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 11, 2018',
#   'reviewerID': 'A3I0VZC187KN4V',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'george.mitchell.7102',
#   'reviewText': 'Very stable, good weight, doesnt slip or tip on a crowded sink. Does just what I wanted.',
#   'summary': 'good weight, doesnt slip or tip on a crowded ...',
#   'unixReviewTime': 1523404800},
#  {'image': ['https://images-na.ssl-images-amazon.com/images/I/717GsQ2qZGL._SY88.jpg'],
#   'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 9, 2018',
#   'reviewerID': 'A2PXPBFZ8STON9',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Stephen A Kim',
#   'reviewText': 'Product is as described. It was sturdy right out of the box. My razor and brush fit perfectly on the stand. The finish looks really high end and matches my razor and brush set.',
#   'summary': 'Great quality!',
#   'unixReviewTime': 1523232000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 9, 2018',
#   'reviewerID': 'A1TJIWRPU9AMMX',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Julio Herrera',
#   'reviewText': 'The stand is well made looks great. Highly recommend this product.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1523232000},
#  {'overall': 5.0,
#   'verified': False,
#   'reviewTime': '04 8, 2018',
#   'reviewerID': 'A1BGMWSPZWQJJ6',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Anatoliy',
#   'reviewText': 'Ordered this stand and came in on time for two day shipping. Perfectly matches the razor that I have (Rockwell 6c White Chrome) and the Escali brush that I ordered also perfectly fits. Amazing stand, works perfectly.',
#   'summary': 'Amazing stand, works perfectly',
#   'unixReviewTime': 1523145600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 7, 2018',
#   'reviewerID': 'A1Z7KJ7SBYTDA8',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Rock',
#   'reviewText': 'Simple and classy. Functional and small enough to fit on a very small counter like ours. My husband was happy and I am too. It shines well. Overall, good purchase.',
#   'summary': 'Good purchase. Shines well. Sized as promised.',
#   'unixReviewTime': 1523059200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 5, 2018',
#   'reviewerID': 'A1YM9NXD7JZVOH',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'William David Welker',
#   'reviewText': 'Very sturdy construction. Heavy on the base. It doesnt rock around on the counter top. Very well chromed . Seems like it should last a long time.',
#   'summary': 'Great quality.',
#   'unixReviewTime': 1522886400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 3, 2018',
#   'reviewerID': 'A183670GNCT2S5',
#   'asin': '1620213982',
#   'style': {'Size:': ' Color42'},
#   'reviewerName': 'Donna Waeger',
#   'reviewText': 'Got my cuckoo clock running again.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1522713600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 2, 2018',
#   'reviewerID': 'A28CV9B46EYAII',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'John Pickens',
#   'reviewText': "So far, so good.  We'll see how it looks in a couple of years.",
#   'summary': "so good. We'll see how it looks in a couple ...",
#   'unixReviewTime': 1522627200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 2, 2018',
#   'reviewerID': 'A1FZGBF4NFVXEM',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'NAME_NOT_RETURNED',
#   'reviewText': 'Just what i wanted. P',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1522627200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 2, 2018',
#   'reviewerID': 'A4V7Y4ADF93HY',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Evgeniy',
#   'reviewText': "The stand is solid and really well-made, I think it suits all the common razors and brushes. It's a really useful thing, a good choice to organize your space in the bathroom.",
#   'summary': "It's a really useful thing, a good choice to organize your space ...",
#   'unixReviewTime': 1522627200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 2, 2018',
#   'reviewerID': 'A2J7SA5UC4QALD',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'D. Burrus',
#   'reviewText': 'Nice quality',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1522627200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '04 1, 2018',
#   'reviewerID': 'A318NIR2SRSNE6',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Mi',
#   'reviewText': 'There were other stands that were more expensive, but the polished look of this is super nice. Also, its very sturdy and holds everything, no problem.',
#   'summary': 'Looks great does the job',
#   'unixReviewTime': 1522540800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 30, 2018',
#   'reviewerID': 'A3A3NOYLZQ6IS8',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Fribster',
#   'reviewText': "It is sturdy and balanced well.  The bracket for the shaver doesn't as easily accommodate razors with wider handles (when I put my razor in, it turns instead of facing in).",
#   'summary': 'It is sturdy and balanced well',
#   'unixReviewTime': 1522368000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 29, 2018',
#   'reviewerID': 'A3U9U3Y35Y3QFH',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'chuck',
#   'reviewText': "Holds a Merkur 34C Long Handle Razor well.  Holds an Omega/Proraso Pro 48 at the comb (where bristles join handle) of the brush.  I prefer, however, a brush to be held far above the comb near the end of the brush handle.  (Most pictures of brush stands show them holding the brush at the comb, but I think that looks weird and top-heavy.  Call me weird, then.)  The arms are too narrow for the Omega.  I have a tool for opening / closing links of chain and I used it, but the result was a very wide V shape and I didn't want to put the somewhat fragile plastic handle in position while I used the tool to squeeze the V shape into more of a C shape.  So I put it back into its original shape.  Ill save as its a very good stand, and if I get a brush that will work the way I want to suspend the brush, I certainly will use this.\nwant to",
#   'summary': 'Well made.  Solid Stand',
#   'unixReviewTime': 1522281600},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 29, 2018',
#   'reviewerID': 'A2LNV4UV0NUIZS',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Roy25',
#   'reviewText': "I like this because it did fit my razor and brush but it comes loose pretty quickly just use a screwdriver and you'll be golden. Does look nice on the bathroom counter.",
#   'summary': 'I like this because it did fit my razor and brush ...',
#   'unixReviewTime': 1522281600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 28, 2018',
#   'reviewerID': 'A38O9NY20850FG',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Jo Clark',
#   'reviewText': 'Very well made and has worked well for these past two years with no issues.',
#   'summary': 'Awesome',
#   'unixReviewTime': 1522195200},
#  {'overall': 1.0,
#   'verified': True,
#   'reviewTime': '03 24, 2018',
#   'reviewerID': 'A58290JXH0SSU',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Skip',
#   'reviewText': 'It rusts.',
#   'summary': 'It rusts.',
#   'unixReviewTime': 1521849600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 23, 2018',
#   'reviewerID': 'A1FYN0MFZ6MQL3',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'sameasalways',
#   'reviewText': "Good quality, I just wish the shaving brush we bought would have fit it.  But it's very nice and makes the bathroom look a lot less cluttered and cleaner.",
#   'summary': 'Giid quality, heavier material.',
#   'unixReviewTime': 1521763200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 23, 2018',
#   'reviewerID': 'A1AGQLSERV5DSX',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Brian Sullivan',
#   'reviewText': 'Great product, very stable and looks great.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1521763200},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 21, 2018',
#   'reviewerID': 'A367B5CIP8UI0E',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Reviewer',
#   'reviewText': 'Looks and feels great.  NOTE: a bit small for my Semogue 2000 brush......  might be a good idea to buy this at the same time as the brush so you know they fit together.',
#   'summary': 'Looks and feels great!',
#   'unixReviewTime': 1521590400},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 20, 2018',
#   'reviewerID': 'AOWY7QZPUFVKY',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'NG',
#   'reviewText': 'Holds you stuff like it should',
#   'summary': 'Four Stars',
#   'unixReviewTime': 1521504000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 20, 2018',
#   'reviewerID': 'A19K6ASI17Q6NT',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Emily Elizabeth',
#   'reviewText': 'Boyfriend loves!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1521504000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 19, 2018',
#   'reviewerID': 'ARTOBVGV46OU0',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'SnowflakeL',
#   'reviewText': 'Great looks, and keeps the razor away from any germs. It gives the bathroom a classier look. I really like it.',
#   'summary': 'Classy and clean.',
#   'unixReviewTime': 1521417600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 18, 2018',
#   'reviewerID': 'AE9EGICEFNPZ2',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Paul',
#   'reviewText': 'Nice stand. Very sturdy and balanced. Looks nice too.',
#   'summary': 'Nice product',
#   'unixReviewTime': 1521331200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 18, 2018',
#   'reviewerID': 'A1T2B5PFIP9TY1',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Jon Rodriguez',
#   'reviewText': "thought it was going to be a big stand but was glad it was very small but not too small for it not to accommodate the razorock plissoft brush and my edwin jagger 89 razor and it fits nicely in a small medicine cabinet. the build quality is excellent. Not sure if its stainless steel but feels and look really solid and top class . only problem is it doesnt fit my brush handle but its not an issue as it fits below the brush handle. the base also has a type of velvet material in the bottom so i don't think it would be a good idea to leave it on your bathroom sink or where it can get wet.",
#   'summary': 'great stand',
#   'unixReviewTime': 1521331200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 17, 2018',
#   'reviewerID': 'A2BQOHBV1O278T',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Dee',
#   'reviewText': 'Bought this for my friend 2 years ago and still looks great.  No tarnishing at all. - Very Nice',
#   'summary': 'He Loves it',
#   'unixReviewTime': 1521244800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 15, 2018',
#   'reviewerID': 'A2RL2YV966PEF8',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'gregory s burris',
#   'reviewText': 'Very nice quality. Highly recommend.',
#   'summary': 'Quality piece',
#   'unixReviewTime': 1521072000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 15, 2018',
#   'reviewerID': 'A1VMITPJ2L8ZNQ',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'LatAmBizPro',
#   'reviewText': 'Perfect.  As described!',
#   'summary': 'Perfect.  As described!',
#   'unixReviewTime': 1521072000},
#  {'overall': 1.0,
#   'verified': True,
#   'reviewTime': '03 14, 2018',
#   'reviewerID': 'AQXFXUIO73LH3',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'VB',
#   'reviewText': "Bought it as a present...doesn't fit a standard Gillette razor",
#   'summary': 'One Star',
#   'unixReviewTime': 1520985600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 14, 2018',
#   'reviewerID': 'A27A00KVC7N2L3',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'INSPIRED',
#   'reviewText': 'Good weighted base. Holds my semogue boar bristle very well. As well as my merkur long handle razor',
#   'summary': 'Great choice',
#   'unixReviewTime': 1520985600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 11, 2018',
#   'reviewerID': 'ASBJ7GTSJWW25',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Unbias Reviewer',
#   'reviewText': 'Very nice stand, especially for the price IF you only have one razor and one brush.\n\n If I was the mfg. I would make this ideal by adding two top additional attachments,  one would be a 4 piece holder for razors and the other would be a four piece holder for brushes.',
#   'summary': 'Useful but could be better',
#   'unixReviewTime': 1520726400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 8, 2018',
#   'reviewerID': 'A16CUS60E2YGTQ',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'TommyT(SC)',
#   'reviewText': 'Classy product.  Works as described.  Has organized and polished the look of a corner of my bath.',
#   'summary': 'Classy product. Works as described. Has organized and ...',
#   'unixReviewTime': 1520467200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 7, 2018',
#   'reviewerID': 'ABE15WG51EFHA',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Dave Grinnell',
#   'reviewText': 'A good purchase. It is well worth the price. Looks good on my sink',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1520380800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 7, 2018',
#   'reviewerID': 'AHRYT06VMVC04',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Jackie',
#   'reviewText': 'Very sturdy and holds my Vikings products.',
#   'summary': 'Perfect!',
#   'unixReviewTime': 1520380800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 6, 2018',
#   'reviewerID': 'AGNWAPYFG6X4C',
#   'asin': '1620213982',
#   'style': {'Size:': ' 86-pc'},
#   'reviewerName': 'Ann Coco',
#   'reviewText': "These are pretty and solid.  I was slightly disappointed that they weren't the same and of the same quality as the ones I got from Reed and Barton for my wedding 28 years ago... but they also are much less expensive.  A solid buy for the price.",
#   'summary': 'These are pretty and solid',
#   'unixReviewTime': 1520294400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 5, 2018',
#   'reviewerID': 'A2EH0U8MQR011C',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Randall P',
#   'reviewText': 'Just as described. Seems to be good quality. Has some weight to it. Shipping was very fast.',
#   'summary': 'Seems to be good quality. Has some weight to it',
#   'unixReviewTime': 1520208000},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 5, 2018',
#   'reviewerID': 'A7SWONZIQ10GU',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Mike McArdle',
#   'reviewText': "I may put a larger base on this, it's a little tippy. I use it all the time and like it though.",
#   'summary': 'I use it all the time and like it though',
#   'unixReviewTime': 1520208000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 4, 2018',
#   'reviewerID': 'A34R3IKBBLMG6K',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Kevin',
#   'reviewText': 'I have decide to rotate brushes.  The first stand was sturdy and unobtrusive, I bought another.',
#   'summary': 'The first stand was sturdy and unobtrusive',
#   'unixReviewTime': 1520121600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 3, 2018',
#   'reviewerID': 'A219METCL6ZIVC',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Hot_Tamale!',
#   'reviewText': 'Love this simple stand goes well with my badger brush and Merkur safety razor.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1520035200},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '03 2, 2018',
#   'reviewerID': 'A2V2TCVSSYBL7T',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'James Borra',
#   'reviewText': 'This stand looks good and works good. I would give 5 stars but it did not accommodate my brush without distorting the metal ring at the base of the bristles, however the brush goes in and I am happy.',
#   'summary': 'This stand looks good and works good',
#   'unixReviewTime': 1519948800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '03 1, 2018',
#   'reviewerID': 'AQKGRMA34631K',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Omar Segundo',
#   'reviewText': 'great little stand.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1519862400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 28, 2018',
#   'reviewerID': 'A3C7NPJDNVMAFI',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Greg7719',
#   'reviewText': 'Good product - meets the needs.',
#   'summary': 'Quality Product',
#   'unixReviewTime': 1519776000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 28, 2018',
#   'reviewerID': 'AAVTF1ADARRTU',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Henry Sanchez',
#   'reviewText': 'Its the right size for the right product.  Its well made with sturdy stainless steel material.  No regrets!',
#   'summary': 'Perfect Holder for my razor and brush',
#   'unixReviewTime': 1519776000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 25, 2018',
#   'reviewerID': 'A1KYIKOUELSAVR',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Nathan Boyd',
#   'reviewText': 'This stand fits my razer handle and brush perfectly and was shipped super fast.',
#   'summary': '... my razer handle and brush perfectly and was shipped super fast.',
#   'unixReviewTime': 1519516800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 22, 2018',
#   'reviewerID': 'AOJEOYBBKK1AC',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'FiniusMcTbag',
#   'reviewText': "Has a good weight so it isn't tippy.",
#   'summary': 'Five Stars',
#   'unixReviewTime': 1519257600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 21, 2018',
#   'reviewerID': 'A28SRSLQ0B1I1S',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Meg Meier',
#   'reviewText': 'My husband loves it!!!!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1519171200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 20, 2018',
#   'reviewerID': 'A2I58CB4AYR3IT',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'casey',
#   'reviewText': 'Came fast, and all ready put together excellent price. ...very satisfied',
#   'summary': 'and all ready put together excellent price.',
#   'unixReviewTime': 1519084800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '02 19, 2018',
#   'reviewerID': 'AP3KNPYPC9WSH',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'U. Harden',
#   'reviewText': 'Very nice razor stand. It is not rusting and has been a great addition to my shaving gear.',
#   'summary': 'Great stand at a great price.',
#   'unixReviewTime': 1518998400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 13, 2018',
#   'reviewerID': 'A3UZJ6MC7OR7BG',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'SMU Mustang',
#   'reviewText': 'Looks exactly the same as the $200+ one they sell at the art of shaving.  Even the engraving matches my Muhle R89.',
#   'summary': 'Looks exactly the same as the $200+ one they sell ...',
#   'unixReviewTime': 1518480000},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '02 13, 2018',
#   'reviewerID': 'A370ZF7IZAM93T',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'gene bradford',
#   'reviewText': 'Works great. Just what I needed',
#   'summary': 'Four Stars',
#   'unixReviewTime': 1518480000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 13, 2018',
#   'reviewerID': 'AYSE2KY78C9W6',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': "Beautiful!\nIt's nice to find old fashioned quality and this is it. The fit and finish is excellent, it's heavy enough it's completely stable. I'm enjoying it every day.",
#   'summary': 'Beautiful quality',
#   'unixReviewTime': 1518480000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 11, 2018',
#   'reviewerID': 'AF1QMVTEVKSZA',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Lo',
#   'reviewText': 'Arrived as described. Fits my Simpson 90mm brush and Edwin Jagger razor perfectly.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1518307200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 11, 2018',
#   'reviewerID': 'A1DGV3J6P8ZQ33',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Handyandy',
#   'reviewText': 'Sturdy stand that is practical and holds your shaving brush properly so it can dry out between use.  Well made and functional.',
#   'summary': 'Shaving Stand',
#   'unixReviewTime': 1518307200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 8, 2018',
#   'reviewerID': 'A199MWAA43KGNM',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'PaulB',
#   'reviewText': 'Nice stand at a reasonable price. Good quality.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1518048000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '02 8, 2018',
#   'reviewerID': 'A2I5RNI62UT5YX',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Anna Teresa Hull',
#   'reviewText': 'Looks very good, sturdy. Nice  as a gift, neatly packed.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1518048000},
#  {'overall': 2.0,
#   'verified': True,
#   'reviewTime': '02 7, 2018',
#   'reviewerID': 'AHEV0FVXWXHS3',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'vha',
#   'reviewText': 'It\'s a nice stand. Well built and good foundation. But does not fit the "Art of Shaving" badger brushes.',
#   'summary': "It's a nice stand. Well built and good foundation",
# ...
#   'verified': True,
#   'reviewTime': '10 13, 2016',
#   'reviewerID': 'A3BC81DX4SGFBZ',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Chris Prieto',
#   'reviewText': "This product has a nice finish and feels like it's well built. I would definitely buy this again.",
#   'summary': 'Five Stars',
#   'unixReviewTime': 1476316800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '10 13, 2016',
#   'reviewerID': 'A18ERGGBHX7203',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Ralph S.',
#   'reviewText': "This stand is good looking and seems to be made of quality metal - however it is not wide enough for the handle of my Parker brush.  I was able to bend the tines to make it work, but it doesn't sit securely.  I think you need to pay attention to the width of your brush handle.  With a narrower handle it would be perfect.",
#   'summary': 'This stand is good looking and seems to be made of quality metal ...',
#   'unixReviewTime': 1476316800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 13, 2016',
#   'reviewerID': 'AOUTEDKCUCVS0',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Theodore C.',
#   'reviewText': 'Very nice, exactly as described. highly recommend.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1476316800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 12, 2016',
#   'reviewerID': 'A3P7RENNC56QHY',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'M Johnson',
#   'reviewText': 'Well weighted and good quality. Looks very nice in person.',
#   'summary': 'Nice Stand',
#   'unixReviewTime': 1476230400},
#  {'overall': 1.0,
#   'verified': True,
#   'reviewTime': '10 12, 2016',
#   'reviewerID': 'A2VAQ3BMSLWZL4',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'BM',
#   'reviewText': 'The larger side is too small to fit any of the brushes i had',
#   'summary': 'One Star',
#   'unixReviewTime': 1476230400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 11, 2016',
#   'reviewerID': 'A1FZM6HX70CK85',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'Very nice. Holds my Gillette Fusion and synthetic shaving brush in the correct position & looks great',
#   'summary': 'EXCELLENT VALUE',
#   'unixReviewTime': 1476144000},
#  {'overall': 5.0,
#   'verified': False,
#   'reviewTime': '10 11, 2016',
#   'reviewerID': 'A2CPBQ5W4OGBX',
#   'asin': '1620213982',
#   'reviewerName': 'Deann',
#   'reviewText': "Nice little cases.  They seem to be made well enough for this price point.  We're happy with them!  (We purchased two sets, for a total of 4 cases).",
#   'summary': 'Convenient storage, well made.',
#   'unixReviewTime': 1476144000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 11, 2016',
#   'reviewerID': 'A2M6ANJX6LJUG5',
#   'asin': '1620213982',
#   'style': {'Size:': ' 13026ffa'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'I like it',
#   'summary': 'I like it',
#   'unixReviewTime': 1476144000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 10, 2016',
#   'reviewerID': 'A1PQR0TQV5I95P',
#   'asin': '1620213982',
#   'style': {'Size:': ' 08d1af09'},
#   'reviewerName': 'coby adkins',
#   'reviewText': 'Great service! My father in law will love it!',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1476057600},
#  {'image': ['https://images-na.ssl-images-amazon.com/images/I/31KB7HptxBL._SY88.jpg'],
#   'overall': 3.0,
#   'verified': True,
#   'reviewTime': '10 10, 2016',
#   'reviewerID': 'A3CNSF40HZJZ6D',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'F. Ryan',
#   'reviewText': "A very good looking stand. Note that while the brush side was perfect, the razor side didn't hold very well. It kept slipping off. I just wrapped a small rubber band around the razor head and now it seats better in the cradle.",
#   'summary': 'Good Looking Item But Razor Side is Slippery',
#   'unixReviewTime': 1476057600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 10, 2016',
#   'reviewerID': 'A1A0DNMO2ESA97',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Benson',
#   'reviewText': 'Excellent product fast shipment',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1476057600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 9, 2016',
#   'reviewerID': 'A2VQYRU21006P9',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Mitch',
#   'reviewText': 'I bought this stand shortly after changing from canned shaving cream to a beaver brush system to help preserve the brush.  It is a very solid, well constructed hanger for both the brush and some razors.  The razor hanging side does not work for my particular razor (Mach 3 which is a rather dated design by a major manufacturer) but the brush holder is a must to help keep you beaver brush rinsed clean and allowed to dry.  The product comes with instructions for disassembly and thorough cleaning of the stand which I really appreciate.  The fact that it does not hold my particular razor does not cause me any real concern because, due to the number of different razor designs on the market these days, I doubt that it is possible to design a system that could work for every conceivable razor on the market.  Who knows, I may change razors next?\nMy primary use for this stand from the start was to keep the beaver brush clean and to allow it to dry thoroughly between uses and it performs admirably for that purpose.  In addition it is well made and based on the quality of construction I anticipate that the finish and the stand will hold up for several years of everyday use.  I took the time to write this because I was impressed with the overall quality which I find to be a rarity these days.',
#   'summary': 'Pleasantly Suprised by the Sturdy Design and Overall Quality',
#   'unixReviewTime': 1475971200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 9, 2016',
#   'reviewerID': 'AQ2094XIJUMTK',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Jason Major',
#   'reviewText': 'Unit arrived brand new, perfect condition.',
#   'summary': 'perfect condition.',
#   'unixReviewTime': 1475971200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 8, 2016',
#   'reviewerID': 'A1SNPSRZ5G8XO9',
#   'asin': '1620213982',
#   'style': {'Size:': ' Purple/Black'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'Love it !',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1475884800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 8, 2016',
#   'reviewerID': 'APV4XTJ5VEKWL',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'GreatScott',
#   'reviewText': 'Holds my Vikings Blade Items perfectly and matches exactly.  Sturdy and heavy so no tipping.',
#   'summary': 'Holds my Vikings Blade Items perfectly and matches exactly',
#   'unixReviewTime': 1475884800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '10 7, 2016',
#   'reviewerID': 'A2ENUAARX5MA01',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': "I have a good razer this was great! Glad I didn't have to pay $100.00 for this.",
#   'summary': 'Great!',
#   'unixReviewTime': 1475798400},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '10 7, 2016',
#   'reviewerID': 'A2VCXSYFAWOT5U',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Rubert R. Reed',
#   'reviewText': 'I am pleased with the item.',
#   'summary': 'Four Stars',
#   'unixReviewTime': 1475798400},
#  {'image': ['https://images-na.ssl-images-amazon.com/images/I/71NS9NbbyaL._SY88.jpg'],
#   'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 6, 2016',
#   'reviewerID': 'A1YLLBCHGPBBMD',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Stephanie',
#   'reviewText': 'Beautiful and well balanced holder for my new DE razor!  Great price and fast shipping too!  The packaging was also quite lovely and would make an excellent gift!',
#   'summary': 'Perfecto Chrime Razor Stand',
#   'unixReviewTime': 1475712000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 6, 2016',
#   'reviewerID': 'A11YEDYO0PZY7W',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Tony',
#   'reviewText': 'This stand is fantastic for stepping up your shaving game. I switched over to safety razors last year and will not go back to anything else. This stand is a perfect compliment to my morning regiment of looking nice and feeling good. The stand is built well and has a solid, weighted base. The stand breaks down for easy cleaning and even for traveling. I would highly recommend this product to all my friends and family.',
#   'summary': 'Solid Stand',
#   'unixReviewTime': 1475712000},
#  {'overall': 3.0,
#   'verified': True,
#   'reviewTime': '10 6, 2016',
#   'reviewerID': 'A3B7V2D92G6X8X',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Cindy Nevels',
#   'reviewText': 'Looks nice on counter!',
#   'summary': 'Great customer service!',
#   'unixReviewTime': 1475712000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 5, 2016',
#   'reviewerID': 'A1LP6IAVWAMW4A',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'well built',
#   'summary': 'good stuff',
#   'unixReviewTime': 1475625600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 5, 2016',
#   'reviewerID': 'A21LWNTRREN9QT',
#   'asin': '1620213982',
#   'reviewerName': 'Tom W',
#   'reviewText': 'These are great!  Fits a lot of sd cards and i have no problem taking them out or putting them in.\n\nPros; cheap, works good\n\nCons: not waterproof.',
#   'summary': 'These are great! Fits a lot of sd cards and i ...',
#   'unixReviewTime': 1475625600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 5, 2016',
#   'reviewerID': 'A28SPR0M064Q8G',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Alberto Lora',
#   'reviewText': "really strong stand. Doesn't wobble or anything",
#   'summary': 'Perfect!',
#   'unixReviewTime': 1475625600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 4, 2016',
#   'reviewerID': 'AUQHT5J6CWH7M',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Joseph F Marcy',
#   'reviewText': 'Arrived today.  No imperfections, easy to tighten, sturdy construction, and a fair price.  What more is there to say.',
#   'summary': 'Perfecto Stand is Perfect',
#   'unixReviewTime': 1475539200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 4, 2016',
#   'reviewerID': 'A2UY4ARFNV6H4B',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Clark O.',
#   'reviewText': 'Razor and Brush set was just what I wanted. It good well with the Chrome steel shaving soap holder I purchased at the same time.\nIt is a very sturdy stand, and should last a life time.',
#   'summary': 'Perfecto Deluxe Chrome Razor Stane',
#   'unixReviewTime': 1475539200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 4, 2016',
#   'reviewerID': 'A3BGHO2QF0R13Z',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': 'Goes great with my new Viking razor. Looks good, everything fits real nice, easy to clean.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1475539200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 3, 2016',
#   'reviewerID': 'A3R02OM4W1IK7N',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Robert Smith',
#   'reviewText': 'Well made!',
#   'summary': 'Pleased',
#   'unixReviewTime': 1475452800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 2, 2016',
#   'reviewerID': 'AGJVVFRHXXKBK',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Amazon Customer',
#   'reviewText': "Works well. The stand came a bit loose, but give it a few rotations and it tightens up perfectly. It's easy to clean, and holds both my brush and razor well. I'd certainly recommend it.",
#   'summary': 'Fantastic Stand',
#   'unixReviewTime': 1475366400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 2, 2016',
#   'reviewerID': 'A1U18GCWGM8ML2',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Revrag',
#   'reviewText': 'Very well constructed.  Both shaving brush and razor fit nicely.',
#   'summary': 'A really great product',
#   'unixReviewTime': 1475366400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 2, 2016',
#   'reviewerID': 'A2SI4APVGUIADA',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Blane Cox',
#   'reviewText': 'Great product with very good chrome. It looks great on the bathroom counter and I would definitely recommend it.',
#   'summary': 'Razor and brush stand',
#   'unixReviewTime': 1475366400},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '10 1, 2016',
#   'reviewerID': 'A10I82PEJ8QSD2',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Luis C.',
#   'reviewText': 'Product arrived liked I went and purchased it myself. No damage to it or the box it came in. I got what I asked for and at a good price.',
#   'summary': 'Just what i asked for.',
#   'unixReviewTime': 1475280000},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 30, 2016',
#   'reviewerID': 'AXKFNVCCNQ3YK',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'R. McElveen',
#   'reviewText': 'Amazing shaving brush stand.  I have had this and used it daily for around a month and it is just like new.  It does a great job and i love this stand.  It looks great and is an excellent quality stand.',
#   'summary': 'Great shaving brush stand',
#   'unixReviewTime': 1475193600},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 29, 2016',
#   'reviewerID': 'ANXTCASU5B0T4',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Rich',
#   'reviewText': 'Holds both my brush and Medium Futur.',
#   'summary': 'Keeps them off the counter.',
#   'unixReviewTime': 1475107200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 29, 2016',
#   'reviewerID': 'A19PTY7LNCG0S2',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Mattdaddy',
#   'reviewText': 'Product as described.  Works and looks great. My bathroom counter is often wet, and so far no rust',
#   'summary': 'Good looking and functional shaving stand',
#   'unixReviewTime': 1475107200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 29, 2016',
#   'reviewerID': 'A37V48GE19VEM9',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'JoShu Reynolds',
#   'reviewText': 'Love it. Sturdy, easy to clean.',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1475107200},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 28, 2016',
#   'reviewerID': 'A3HTQ0J0ZT59PC',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'S.S.',
#   'reviewText': 'Works just fine and looks sharp',
#   'summary': 'Five Stars',
#   'unixReviewTime': 1475020800},
#  {'overall': 5.0,
#   'verified': True,
#   'reviewTime': '09 28, 2016',
#   'reviewerID': 'AMDHHRZYHR4A9',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Josh',
#   'reviewText': 'I have a mable counter top and the stand looks great on it also it has a felt pad on the bottom of it so it doesnt scratch the counter top great product',
#   'summary': 'wonderful does the job',
#   'unixReviewTime': 1475020800},
#  {'overall': 4.0,
#   'verified': True,
#   'reviewTime': '09 28, 2016',
#   'reviewerID': 'A1HGCCR89BJEFV',
#   'asin': '1620213982',
#   'style': {'Size:': ' 6.25 Inches'},
#   'reviewerName': 'Seyrel',
#   'reviewText': 'Good product.  As described...  thank you',
#   'summary': 'Four Stars',
#   'unixReviewTime': 1475020800},
#  ...]

# %%
def try_key_or_make_empty(dict_name, key_name):
    try:
        overall = dict_name[key_name]
    except:
        overall = ''
    return overall
# Out:
# ['reviewTime',
#  'reviewerName',
#  'unixReviewTime',
#  'overall',
#  'reviewText',
#  'vote',
#  'image',
#  'style',
#  'summary',
#  'reviewerID',
#  'verified',
#  'asin']

# %%
#reviewerID=A1V6B6TNIC10QE
for y in data_tmp:
#    if (y["reviewerID"] == "A1V6B6TNIC10QE"):
    if ( "{" in str(y["rank"]) ):
        print( y)
        break
# Out:
# {'overall': 1.0, 'verified': True, 'reviewTime': '02 19, 2015', 'reviewerID': 'A1V6B6TNIC10QE', 'asin': '0143026860', 'reviewerName': 'theodore j bigham', 'reviewText': 'great', 'summary': 'One Star', 'unixReviewTime': 1424304000}

# %%
pre_json_data = {k:[] for k in keys }
columns = list({k for k in keys })
for y in data_tmp:
    for c in columns:
        pre_json_data[c].append(try_key_or_make_empty(y,c))

# %%
pre_json_data
# Out:
# {'overall': [1.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   1.0,
#   5.0,
#   1.0,
#   2.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   4.0,
#   5.0,
#   2.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   4.0,
#   4.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   2.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   1.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   4.0,
#   3.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   2.0,
#   3.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   4.0,
#   3.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   2.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   5.0,
#   5.0,
#   1.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   4.0,
#   5.0,
#   5.0,
#   3.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   5.0,
#   4.0,
#   ...],
#  'verified': [True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   False,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   True,
#   ...],
#  'reviewTime': ['02 19, 2015',
#   '12 18, 2014',
#   '08 10, 2014',
#   '03 11, 2013',
#   '12 25, 2011',
#   '02 26, 2010',
#   '03 7, 2001',
#   '04 10, 2017',
#   '01 3, 2017',
#   '11 19, 2016',
#   '11 10, 2016',
#   '09 26, 2016',
#   '08 5, 2016',
#   '07 29, 2016',
#   '06 18, 2016',
#   '05 25, 2016',
#   '03 26, 2016',
#   '02 1, 2015',
#   '01 30, 2015',
#   '12 1, 2014',
#   '11 12, 2014',
#   '09 4, 2014',
#   '07 24, 2014',
#   '05 16, 2012',
#   '02 26, 2012',
#   '01 16, 2012',
#   '11 24, 2011',
#   '10 29, 2011',
#   '08 27, 2011',
#   '04 29, 2011',
#   '10 31, 2010',
#   '09 14, 2010',
#   '05 8, 2018',
#   '05 8, 2018',
#   '05 6, 2018',
#   '05 3, 2018',
#   '05 2, 2018',
#   '05 1, 2018',
#   '04 28, 2018',
#   '04 28, 2018',
#   '04 26, 2018',
#   '04 26, 2018',
#   '04 26, 2018',
#   '04 25, 2018',
#   '04 18, 2018',
#   '04 17, 2018',
#   '04 17, 2018',
#   '04 16, 2018',
#   '04 14, 2018',
#   '04 12, 2018',
#   '04 12, 2018',
#   '04 12, 2018',
#   '04 11, 2018',
#   '04 9, 2018',
#   '04 9, 2018',
#   '04 8, 2018',
#   '04 7, 2018',
#   '04 5, 2018',
#   '04 3, 2018',
#   '04 2, 2018',
#   '04 2, 2018',
#   '04 2, 2018',
#   '04 2, 2018',
#   '04 1, 2018',
#   '03 30, 2018',
#   '03 29, 2018',
#   '03 29, 2018',
#   '03 28, 2018',
#   '03 24, 2018',
#   '03 23, 2018',
#   '03 23, 2018',
#   '03 21, 2018',
#   '03 20, 2018',
#   '03 20, 2018',
#   '03 19, 2018',
#   '03 18, 2018',
#   '03 18, 2018',
#   '03 17, 2018',
#   '03 15, 2018',
#   '03 15, 2018',
#   '03 14, 2018',
#   '03 14, 2018',
#   '03 11, 2018',
#   '03 8, 2018',
#   '03 7, 2018',
#   '03 7, 2018',
#   '03 6, 2018',
#   '03 5, 2018',
#   '03 5, 2018',
#   '03 4, 2018',
#   '03 3, 2018',
#   '03 2, 2018',
#   '03 1, 2018',
#   '02 28, 2018',
#   '02 28, 2018',
#   '02 25, 2018',
#   '02 22, 2018',
#   '02 21, 2018',
#   '02 20, 2018',
#   '02 19, 2018',
#   '02 13, 2018',
#   '02 13, 2018',
#   '02 13, 2018',
#   '02 11, 2018',
#   '02 11, 2018',
#   '02 8, 2018',
#   '02 8, 2018',
#   '02 7, 2018',
#   '02 7, 2018',
#   '02 6, 2018',
#   '01 29, 2018',
#   '01 29, 2018',
#   '01 27, 2018',
#   '01 26, 2018',
#   '01 26, 2018',
#   '01 25, 2018',
#   '01 25, 2018',
#   '01 24, 2018',
#   '01 23, 2018',
#   '01 22, 2018',
#   '01 21, 2018',
#   '01 20, 2018',
#   '01 20, 2018',
#   '01 18, 2018',
#   '01 17, 2018',
#   '01 17, 2018',
#   '01 15, 2018',
#   '01 15, 2018',
#   '01 14, 2018',
#   '01 14, 2018',
#   '01 14, 2018',
#   '01 12, 2018',
#   '01 9, 2018',
#   '01 9, 2018',
#   '01 9, 2018',
#   '01 8, 2018',
#   '01 7, 2018',
#   '01 7, 2018',
#   '01 3, 2018',
#   '12 30, 2017',
#   '12 29, 2017',
#   '12 29, 2017',
#   '12 28, 2017',
#   '12 28, 2017',
#   '12 27, 2017',
#   '12 26, 2017',
#   '12 26, 2017',
#   '12 26, 2017',
#   '12 26, 2017',
#   '12 26, 2017',
#   '12 24, 2017',
#   '12 24, 2017',
#   '12 24, 2017',
#   '12 22, 2017',
#   '12 19, 2017',
#   '12 18, 2017',
#   '12 17, 2017',
#   '12 14, 2017',
#   '12 13, 2017',
#   '12 12, 2017',
#   '12 11, 2017',
#   '12 10, 2017',
#   '12 8, 2017',
#   '12 7, 2017',
#   '12 6, 2017',
#   '12 6, 2017',
#   '12 4, 2017',
#   '12 4, 2017',
#   '12 3, 2017',
#   '11 30, 2017',
#   '11 25, 2017',
#   '11 24, 2017',
#   '11 22, 2017',
#   '11 22, 2017',
#   '11 21, 2017',
#   '11 20, 2017',
#   '11 20, 2017',
#   '11 16, 2017',
#   '11 15, 2017',
#   '11 14, 2017',
#   '11 12, 2017',
#   '11 9, 2017',
#   '11 5, 2017',
#   '11 5, 2017',
#   '11 4, 2017',
#   '10 31, 2017',
#   '10 31, 2017',
#   '10 26, 2017',
#   '10 25, 2017',
#   '10 25, 2017',
#   '10 24, 2017',
#   '10 24, 2017',
#   '10 23, 2017',
#   '10 23, 2017',
#   '10 23, 2017',
#   '10 23, 2017',
#   '10 22, 2017',
#   '10 21, 2017',
#   '10 19, 2017',
#   '10 19, 2017',
#   '10 19, 2017',
#   '10 15, 2017',
#   '10 15, 2017',
#   '10 14, 2017',
#   '10 11, 2017',
#   '10 11, 2017',
#   '10 9, 2017',
#   '10 9, 2017',
#   '10 8, 2017',
#   '10 7, 2017',
#   '10 6, 2017',
#   '10 5, 2017',
#   '10 1, 2017',
#   '09 30, 2017',
#   '09 30, 2017',
#   '09 29, 2017',
#   '09 27, 2017',
#   '09 26, 2017',
#   '09 25, 2017',
#   '09 24, 2017',
#   '09 21, 2017',
#   '09 20, 2017',
#   '09 19, 2017',
#   '09 18, 2017',
#   '09 17, 2017',
#   '09 16, 2017',
#   '09 15, 2017',
#   '09 15, 2017',
#   '09 14, 2017',
#   '09 14, 2017',
#   '09 14, 2017',
#   '09 13, 2017',
#   '09 12, 2017',
#   '09 11, 2017',
#   '09 11, 2017',
#   '09 8, 2017',
#   '09 7, 2017',
#   '09 7, 2017',
#   '09 5, 2017',
#   '09 5, 2017',
#   '09 5, 2017',
#   '09 5, 2017',
#   '09 2, 2017',
#   '09 1, 2017',
#   '09 1, 2017',
#   '08 31, 2017',
#   '08 31, 2017',
#   '08 30, 2017',
#   '08 29, 2017',
#   '08 26, 2017',
#   '08 24, 2017',
#   '08 23, 2017',
#   '08 23, 2017',
#   '08 21, 2017',
#   '08 21, 2017',
#   '08 20, 2017',
#   '08 20, 2017',
#   '08 18, 2017',
#   '08 18, 2017',
#   '08 16, 2017',
#   '08 16, 2017',
#   '08 14, 2017',
#   '08 14, 2017',
#   '08 13, 2017',
#   '08 13, 2017',
#   '08 13, 2017',
#   '08 13, 2017',
#   '08 11, 2017',
#   '08 10, 2017',
#   '08 10, 2017',
#   '08 10, 2017',
#   '08 9, 2017',
#   '08 8, 2017',
#   '08 7, 2017',
#   '08 7, 2017',
#   '08 6, 2017',
#   '08 6, 2017',
#   '08 6, 2017',
#   '08 6, 2017',
#   '08 5, 2017',
#   '08 4, 2017',
#   '08 3, 2017',
#   '08 2, 2017',
#   '08 1, 2017',
#   '08 1, 2017',
#   '07 31, 2017',
#   '07 30, 2017',
#   '07 29, 2017',
#   '07 28, 2017',
#   '07 27, 2017',
#   '07 26, 2017',
#   '07 26, 2017',
#   '07 26, 2017',
#   '07 23, 2017',
#   '07 21, 2017',
#   '07 21, 2017',
#   '07 20, 2017',
#   '07 19, 2017',
#   '07 18, 2017',
#   '07 17, 2017',
#   '07 17, 2017',
#   '07 17, 2017',
#   '07 16, 2017',
#   '07 16, 2017',
#   '07 16, 2017',
#   '07 15, 2017',
#   '07 14, 2017',
#   '07 14, 2017',
#   '07 14, 2017',
#   '07 12, 2017',
#   '07 11, 2017',
#   '07 10, 2017',
#   '07 10, 2017',
#   '07 9, 2017',
#   '07 9, 2017',
#   '07 8, 2017',
#   '07 7, 2017',
#   '07 7, 2017',
#   '07 6, 2017',
#   '07 5, 2017',
#   '07 4, 2017',
#   '07 3, 2017',
#   '07 3, 2017',
#   '07 3, 2017',
#   '07 2, 2017',
#   '07 1, 2017',
#   '06 29, 2017',
#   '06 27, 2017',
#   '06 27, 2017',
#   '06 26, 2017',
#   '06 26, 2017',
#   '06 26, 2017',
#   '06 25, 2017',
#   '06 25, 2017',
#   '06 23, 2017',
#   '06 23, 2017',
#   '06 22, 2017',
#   '06 22, 2017',
#   '06 22, 2017',
#   '06 22, 2017',
#   '06 20, 2017',
#   '06 20, 2017',
#   '06 19, 2017',
#   '06 17, 2017',
#   '06 15, 2017',
#   '06 15, 2017',
#   '06 14, 2017',
#   '06 14, 2017',
#   '06 12, 2017',
#   '06 12, 2017',
#   '06 11, 2017',
#   '06 10, 2017',
#   '06 9, 2017',
#   '06 8, 2017',
#   '06 8, 2017',
#   '06 8, 2017',
#   '06 6, 2017',
#   '06 3, 2017',
#   '06 2, 2017',
#   '06 2, 2017',
#   '05 31, 2017',
#   '05 30, 2017',
#   '05 29, 2017',
#   '05 28, 2017',
#   '05 28, 2017',
#   '05 28, 2017',
#   '05 28, 2017',
#   '05 27, 2017',
#   '05 26, 2017',
#   '05 23, 2017',
#   '05 22, 2017',
#   '05 21, 2017',
#   '05 21, 2017',
#   '05 21, 2017',
#   '05 21, 2017',
#   '05 19, 2017',
#   '05 18, 2017',
#   '05 18, 2017',
#   '05 17, 2017',
#   '05 17, 2017',
#   '05 16, 2017',
#   '05 16, 2017',
#   '05 16, 2017',
#   '05 15, 2017',
#   '05 15, 2017',
#   '05 15, 2017',
#   '05 14, 2017',
#   '05 11, 2017',
#   '05 10, 2017',
#   '05 10, 2017',
#   '05 10, 2017',
#   '05 9, 2017',
#   '05 9, 2017',
#   '05 9, 2017',
#   '05 8, 2017',
#   '05 7, 2017',
#   '05 7, 2017',
#   '05 5, 2017',
#   '05 5, 2017',
#   '05 5, 2017',
#   '05 5, 2017',
#   '05 5, 2017',
#   '05 4, 2017',
#   '05 4, 2017',
#   '05 3, 2017',
#   '05 3, 2017',
#   '05 2, 2017',
#   '05 2, 2017',
#   '05 1, 2017',
#   '05 1, 2017',
#   '04 30, 2017',
#   '04 30, 2017',
#   '04 30, 2017',
#   '04 28, 2017',
#   '04 28, 2017',
#   '04 27, 2017',
#   '04 26, 2017',
#   '04 26, 2017',
#   '04 26, 2017',
#   '04 25, 2017',
#   '04 25, 2017',
#   '04 24, 2017',
#   '04 24, 2017',
#   '04 23, 2017',
#   '04 23, 2017',
#   '04 22, 2017',
#   '04 21, 2017',
#   '04 21, 2017',
#   '04 20, 2017',
#   '04 20, 2017',
#   '04 20, 2017',
#   '04 19, 2017',
#   '04 19, 2017',
#   '04 19, 2017',
#   '04 19, 2017',
#   '04 17, 2017',
#   '04 16, 2017',
#   '04 15, 2017',
#   '04 15, 2017',
#   '04 14, 2017',
#   '04 14, 2017',
#   '04 13, 2017',
#   '04 13, 2017',
#   '04 13, 2017',
#   '04 12, 2017',
#   '04 12, 2017',
#   '04 11, 2017',
#   '04 11, 2017',
#   '04 10, 2017',
#   '04 9, 2017',
#   '04 9, 2017',
#   '04 8, 2017',
#   '04 8, 2017',
#   '04 8, 2017',
#   '04 7, 2017',
#   '04 6, 2017',
#   '04 6, 2017',
#   '04 5, 2017',
#   '04 5, 2017',
#   '04 5, 2017',
#   '04 4, 2017',
#   '04 3, 2017',
#   '04 3, 2017',
#   '04 2, 2017',
#   '04 2, 2017',
#   '04 2, 2017',
#   '04 1, 2017',
#   '04 1, 2017',
#   '03 31, 2017',
#   '03 31, 2017',
#   '03 31, 2017',
#   '03 31, 2017',
#   '03 30, 2017',
#   '03 29, 2017',
#   '03 29, 2017',
#   '03 29, 2017',
#   '03 29, 2017',
#   '03 28, 2017',
#   '03 28, 2017',
#   '03 28, 2017',
#   '03 28, 2017',
#   '03 27, 2017',
#   '03 27, 2017',
#   '03 27, 2017',
#   '03 27, 2017',
#   '03 27, 2017',
#   '03 26, 2017',
#   '03 25, 2017',
#   '03 25, 2017',
#   '03 24, 2017',
#   '03 24, 2017',
#   '03 24, 2017',
#   '03 21, 2017',
#   '03 21, 2017',
#   '03 21, 2017',
#   '03 21, 2017',
#   '03 21, 2017',
#   '03 20, 2017',
#   '03 19, 2017',
#   '03 19, 2017',
#   '03 19, 2017',
#   '03 19, 2017',
#   '03 19, 2017',
#   '03 18, 2017',
#   '03 17, 2017',
#   '03 17, 2017',
#   '03 16, 2017',
#   '03 16, 2017',
#   '03 16, 2017',
#   '03 16, 2017',
#   '03 15, 2017',
#   '03 15, 2017',
#   '03 15, 2017',
#   '03 15, 2017',
#   '03 15, 2017',
#   '03 14, 2017',
#   '03 13, 2017',
#   '03 13, 2017',
#   '03 13, 2017',
#   '03 12, 2017',
#   '03 12, 2017',
#   '03 12, 2017',
#   '03 12, 2017',
#   '03 10, 2017',
#   '03 10, 2017',
#   '03 10, 2017',
#   '03 10, 2017',
#   '03 10, 2017',
#   '03 9, 2017',
#   '03 9, 2017',
#   '03 9, 2017',
#   '03 8, 2017',
#   '03 8, 2017',
#   '03 8, 2017',
#   '03 8, 2017',
#   '03 7, 2017',
#   '03 7, 2017',
#   '03 7, 2017',
#   '03 6, 2017',
#   '03 6, 2017',
#   '03 6, 2017',
#   '03 6, 2017',
#   '03 6, 2017',
#   '03 6, 2017',
#   '03 5, 2017',
#   '03 5, 2017',
#   '03 5, 2017',
#   '03 4, 2017',
#   '03 3, 2017',
#   '03 3, 2017',
#   '03 3, 2017',
#   '03 2, 2017',
#   '03 2, 2017',
#   '03 2, 2017',
#   '03 2, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '03 1, 2017',
#   '02 28, 2017',
#   '02 28, 2017',
#   '02 28, 2017',
#   '02 28, 2017',
#   '02 28, 2017',
#   '02 27, 2017',
#   '02 27, 2017',
#   '02 27, 2017',
#   '02 27, 2017',
#   '02 27, 2017',
#   '02 26, 2017',
#   '02 26, 2017',
#   '02 26, 2017',
#   '02 25, 2017',
#   '02 24, 2017',
#   '02 24, 2017',
#   '02 23, 2017',
#   '02 23, 2017',
#   '02 23, 2017',
#   '02 23, 2017',
#   '02 22, 2017',
#   '02 22, 2017',
#   '02 22, 2017',
#   '02 22, 2017',
#   '02 21, 2017',
#   '02 21, 2017',
#   '02 20, 2017',
#   '02 20, 2017',
#   '02 20, 2017',
#   '02 20, 2017',
#   '02 20, 2017',
#   '02 19, 2017',
#   '02 19, 2017',
#   '02 19, 2017',
#   '02 18, 2017',
#   '02 17, 2017',
#   '02 17, 2017',
#   '02 17, 2017',
#   '02 17, 2017',
#   '02 17, 2017',
#   '02 16, 2017',
#   '02 16, 2017',
#   '02 15, 2017',
#   '02 15, 2017',
#   '02 15, 2017',
#   '02 14, 2017',
#   '02 14, 2017',
#   '02 14, 2017',
#   '02 13, 2017',
#   '02 13, 2017',
#   '02 13, 2017',
#   '02 12, 2017',
#   '02 12, 2017',
#   '02 12, 2017',
#   '02 12, 2017',
#   '02 12, 2017',
#   '02 11, 2017',
#   '02 10, 2017',
#   '02 10, 2017',
#   '02 10, 2017',
#   '02 10, 2017',
#   '02 10, 2017',
#   '02 9, 2017',
#   '02 9, 2017',
#   '02 8, 2017',
#   '02 7, 2017',
#   '02 7, 2017',
#   '02 7, 2017',
#   '02 7, 2017',
#   '02 7, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 6, 2017',
#   '02 5, 2017',
#   '02 5, 2017',
#   '02 5, 2017',
#   '02 4, 2017',
#   '02 2, 2017',
#   '02 2, 2017',
#   '02 1, 2017',
#   '02 1, 2017',
#   '02 1, 2017',
#   '02 1, 2017',
#   '01 31, 2017',
#   '01 31, 2017',
#   '01 30, 2017',
#   '01 30, 2017',
#   '01 30, 2017',
#   '01 30, 2017',
#   '01 29, 2017',
#   '01 29, 2017',
#   '01 29, 2017',
#   '01 29, 2017',
#   '01 28, 2017',
#   '01 28, 2017',
#   '01 28, 2017',
#   '01 28, 2017',
#   '01 27, 2017',
#   '01 27, 2017',
#   '01 27, 2017',
#   '01 27, 2017',
#   '01 27, 2017',
#   '01 26, 2017',
#   '01 26, 2017',
#   '01 26, 2017',
#   '01 26, 2017',
#   '01 25, 2017',
#   '01 25, 2017',
#   '01 24, 2017',
#   '01 24, 2017',
#   '01 24, 2017',
#   '01 24, 2017',
#   '01 24, 2017',
#   '01 23, 2017',
#   '01 23, 2017',
#   '01 23, 2017',
#   '01 22, 2017',
#   '01 22, 2017',
#   '01 21, 2017',
#   '01 21, 2017',
#   '01 20, 2017',
#   '01 20, 2017',
#   '01 20, 2017',
#   '01 20, 2017',
#   '01 20, 2017',
#   '01 19, 2017',
#   '01 19, 2017',
#   '01 19, 2017',
#   '01 18, 2017',
#   '01 18, 2017',
#   '01 18, 2017',
#   '01 18, 2017',
#   '01 18, 2017',
#   '01 17, 2017',
#   '01 17, 2017',
#   '01 17, 2017',
#   '01 17, 2017',
#   '01 17, 2017',
#   '01 16, 2017',
#   '01 16, 2017',
#   '01 16, 2017',
#   '01 16, 2017',
#   '01 15, 2017',
#   '01 15, 2017',
#   '01 15, 2017',
#   '01 15, 2017',
#   '01 15, 2017',
#   '01 15, 2017',
#   '01 14, 2017',
#   '01 14, 2017',
#   '01 14, 2017',
#   '01 14, 2017',
#   '01 12, 2017',
#   '01 12, 2017',
#   '01 12, 2017',
#   '01 12, 2017',
#   '01 11, 2017',
#   '01 11, 2017',
#   '01 11, 2017',
#   '01 11, 2017',
#   '01 11, 2017',
#   '01 10, 2017',
#   '01 10, 2017',
#   '01 10, 2017',
#   '01 9, 2017',
#   '01 9, 2017',
#   '01 9, 2017',
#   '01 9, 2017',
#   '01 8, 2017',
#   '01 8, 2017',
#   '01 8, 2017',
#   '01 8, 2017',
#   '01 7, 2017',
#   '01 7, 2017',
#   '01 6, 2017',
#   '01 6, 2017',
#   '01 6, 2017',
#   '01 6, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 5, 2017',
#   '01 4, 2017',
#   '01 4, 2017',
#   '01 4, 2017',
#   '01 4, 2017',
#   '01 4, 2017',
#   '01 3, 2017',
#   '01 3, 2017',
#   '01 3, 2017',
#   '01 3, 2017',
#   '01 3, 2017',
#   '01 2, 2017',
#   '01 2, 2017',
#   '01 2, 2017',
#   '01 2, 2017',
#   '01 2, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '01 1, 2017',
#   '12 31, 2016',
#   '12 31, 2016',
#   '12 31, 2016',
#   '12 30, 2016',
#   '12 30, 2016',
#   '12 29, 2016',
#   '12 29, 2016',
#   '12 29, 2016',
#   '12 29, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 28, 2016',
#   '12 27, 2016',
#   '12 27, 2016',
#   '12 27, 2016',
#   '12 27, 2016',
#   '12 27, 2016',
#   '12 26, 2016',
#   '12 26, 2016',
#   '12 26, 2016',
#   '12 26, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 25, 2016',
#   '12 23, 2016',
#   '12 23, 2016',
#   '12 23, 2016',
#   '12 23, 2016',
#   '12 23, 2016',
#   '12 22, 2016',
#   '12 22, 2016',
#   '12 22, 2016',
#   '12 20, 2016',
#   '12 20, 2016',
#   '12 20, 2016',
#   '12 19, 2016',
#   '12 19, 2016',
#   '12 19, 2016',
#   '12 19, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 18, 2016',
#   '12 16, 2016',
#   '12 15, 2016',
#   '12 15, 2016',
#   '12 15, 2016',
#   '12 15, 2016',
#   '12 15, 2016',
#   '12 14, 2016',
#   '12 13, 2016',
#   '12 13, 2016',
#   '12 13, 2016',
#   '12 13, 2016',
#   '12 13, 2016',
#   '12 12, 2016',
#   '12 12, 2016',
#   '12 11, 2016',
#   '12 10, 2016',
#   '12 9, 2016',
#   '12 8, 2016',
#   '12 7, 2016',
#   '12 7, 2016',
#   '12 7, 2016',
#   '12 6, 2016',
#   '12 6, 2016',
#   '12 6, 2016',
#   '12 6, 2016',
#   '12 5, 2016',
#   '12 4, 2016',
#   '12 4, 2016',
#   '12 4, 2016',
#   '12 2, 2016',
#   '12 1, 2016',
#   '11 30, 2016',
#   '11 30, 2016',
#   '11 29, 2016',
#   '11 29, 2016',
#   '11 28, 2016',
#   '11 28, 2016',
#   '11 27, 2016',
#   '11 27, 2016',
#   '11 26, 2016',
#   '11 26, 2016',
#   '11 25, 2016',
#   '11 24, 2016',
#   '11 24, 2016',
#   '11 23, 2016',
#   '11 23, 2016',
#   '11 23, 2016',
#   '11 23, 2016',
#   '11 21, 2016',
#   '11 21, 2016',
#   '11 21, 2016',
#   '11 20, 2016',
#   '11 20, 2016',
#   '11 20, 2016',
#   '11 20, 2016',
#   '11 19, 2016',
#   '11 19, 2016',
#   '11 19, 2016',
#   '11 19, 2016',
#   '11 18, 2016',
#   '11 18, 2016',
#   '11 18, 2016',
#   '11 17, 2016',
#   '11 17, 2016',
#   '11 16, 2016',
#   '11 16, 2016',
#   '11 16, 2016',
#   '11 16, 2016',
#   '11 16, 2016',
#   '11 15, 2016',
#   '11 15, 2016',
#   '11 15, 2016',
#   '11 15, 2016',
#   '11 14, 2016',
#   '11 14, 2016',
#   '11 14, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 13, 2016',
#   '11 11, 2016',
#   '11 10, 2016',
#   '11 10, 2016',
#   '11 9, 2016',
#   '11 9, 2016',
#   '11 8, 2016',
#   '11 7, 2016',
#   '11 6, 2016',
#   '11 6, 2016',
#   '11 6, 2016',
#   '11 5, 2016',
#   '11 5, 2016',
#   '11 4, 2016',
#   '11 3, 2016',
#   '11 3, 2016',
#   '11 3, 2016',
#   '11 1, 2016',
#   '11 1, 2016',
#   '11 1, 2016',
#   '10 31, 2016',
#   '10 31, 2016',
#   '10 30, 2016',
#   '10 30, 2016',
#   '10 30, 2016',
#   '10 30, 2016',
#   '10 28, 2016',
#   '10 27, 2016',
#   '10 27, 2016',
#   '10 27, 2016',
#   '10 26, 2016',
#   '10 25, 2016',
#   '10 25, 2016',
#   '10 23, 2016',
#   '10 22, 2016',
#   '10 21, 2016',
#   '10 20, 2016',
#   '10 20, 2016',
#   '10 20, 2016',
#   '10 19, 2016',
#   '10 19, 2016',
#   '10 18, 2016',
#   '10 17, 2016',
#   '10 16, 2016',
#   '10 16, 2016',
#   '10 16, 2016',
#   '10 14, 2016',
#   '10 13, 2016',
#   '10 13, 2016',
#   '10 13, 2016',
#   '10 13, 2016',
#   '10 12, 2016',
#   '10 12, 2016',
#   '10 11, 2016',
#   '10 11, 2016',
#   '10 11, 2016',
#   '10 10, 2016',
#   '10 10, 2016',
#   '10 10, 2016',
#   '10 9, 2016',
#   '10 9, 2016',
#   '10 8, 2016',
#   '10 8, 2016',
#   '10 7, 2016',
#   '10 7, 2016',
#   '10 6, 2016',
#   '10 6, 2016',
#   '10 6, 2016',
#   '10 5, 2016',
#   '10 5, 2016',
#   '10 5, 2016',
#   '10 4, 2016',
#   '10 4, 2016',
#   '10 4, 2016',
#   '10 3, 2016',
#   '10 2, 2016',
#   '10 2, 2016',
#   '10 2, 2016',
#   '10 1, 2016',
#   '09 30, 2016',
#   '09 29, 2016',
#   '09 29, 2016',
#   '09 29, 2016',
#   '09 28, 2016',
#   '09 28, 2016',
#   '09 28, 2016',
#   ...],
#  'reviewerID': ['A1V6B6TNIC10QE',
#   'A2F5GHSXFQ0W6J',
#   'A1572GUYS7DGSR',
#   'A1PSGLFK1NSVO',
#   'A6IKXKZMTKGSC',
#   'A36NF437WZLQ9E',
#   'A10Q8NIFOVOHFV',
#   'A26PO1B2Q2G1CS',
#   'AQ812VYVTC2RJ',
#   'AMACNEW14ADMX',
#   'A5FS4FVWR77O6',
#   'A1NLF2JD7BVOB4',
#   'A3CKVF2ZR1CBO0',
#   'A3IFT6SR16SAYU',
#   'A2BQ7NB90SBVIA',
#   'A92AYWTA52KXE',
#   'AR6LNUWXJFYE6',
#   'A2V9BG2MDQVCYX',
#   'AIL9Q82L1G2YO',
#   'A1ROGN2QPKZGP7',
#   'A141Z5WI6GVM6Y',
#   'A1M3JNGXB8IU7I',
#   'A3NYLVMP922AE5',
#   'A1DN3KBTCYBH6K',
#   'A1TA38LWZO0NZS',
#   'A2OZBC5SG575G1',
#   'A2YKYIA11M9XTX',
#   'A32MUH70JIV7TS',
#   'A3S57667R6V4S4',
#   'A3JLEHAK528W8Z',
#   'A1XA71UE5A7F5B',
#   'A3BEXXPM77KR5Z',
#   'A9KCT397IWK97',
#   'A36Z95ZFDMNL99',
#   'AB6RYXLZSKHIR',
#   'A210V878QFZW9V',
#   'A18WMBY4BAB7ES',
#   'A2667UCM2FYMQ5',
#   'AQ3IBZ523E9NP',
#   'A2Q6ZCAOTIKW5A',
#   'A2HJQ1TBXTHXFQ',
#   'A33JNJ0DGA6JRU',
#   'A1KF66E65YEALF',
#   'AYYITJTFJCA77',
#   'A35GAM2X7G7LAI',
#   'A1Z8A548Z31SUB',
#   'A2XBDWQ3Z8GZM',
#   'A2FT0AFHQ32G33',
#   'AIVFUM7JDR4KM',
#   'A12GV837WV9DA2',
#   'A14BXZB8SZCCY1',
#   'A37P4JQKJQ6ICE',
#   'A3I0VZC187KN4V',
#   'A2PXPBFZ8STON9',
#   'A1TJIWRPU9AMMX',
#   'A1BGMWSPZWQJJ6',
#   'A1Z7KJ7SBYTDA8',
#   'A1YM9NXD7JZVOH',
#   'A183670GNCT2S5',
#   'A28CV9B46EYAII',
#   'A1FZGBF4NFVXEM',
#   'A4V7Y4ADF93HY',
#   'A2J7SA5UC4QALD',
#   'A318NIR2SRSNE6',
#   'A3A3NOYLZQ6IS8',
#   'A3U9U3Y35Y3QFH',
#   'A2LNV4UV0NUIZS',
#   'A38O9NY20850FG',
#   'A58290JXH0SSU',
#   'A1FYN0MFZ6MQL3',
#   'A1AGQLSERV5DSX',
#   'A367B5CIP8UI0E',
#   'AOWY7QZPUFVKY',
#   'A19K6ASI17Q6NT',
#   'ARTOBVGV46OU0',
#   'AE9EGICEFNPZ2',
#   'A1T2B5PFIP9TY1',
#   'A2BQOHBV1O278T',
#   'A2RL2YV966PEF8',
#   'A1VMITPJ2L8ZNQ',
#   'AQXFXUIO73LH3',
#   'A27A00KVC7N2L3',
#   'ASBJ7GTSJWW25',
#   'A16CUS60E2YGTQ',
#   'ABE15WG51EFHA',
#   'AHRYT06VMVC04',
#   'AGNWAPYFG6X4C',
#   'A2EH0U8MQR011C',
#   'A7SWONZIQ10GU',
#   'A34R3IKBBLMG6K',
#   'A219METCL6ZIVC',
#   'A2V2TCVSSYBL7T',
#   'AQKGRMA34631K',
#   'A3C7NPJDNVMAFI',
#   'AAVTF1ADARRTU',
#   'A1KYIKOUELSAVR',
#   'AOJEOYBBKK1AC',
#   'A28SRSLQ0B1I1S',
#   'A2I58CB4AYR3IT',
#   'AP3KNPYPC9WSH',
#   'A3UZJ6MC7OR7BG',
#   'A370ZF7IZAM93T',
#   'AYSE2KY78C9W6',
#   'AF1QMVTEVKSZA',
#   'A1DGV3J6P8ZQ33',
#   'A199MWAA43KGNM',
#   'A2I5RNI62UT5YX',
#   'AHEV0FVXWXHS3',
#   'AKHMZMW59BAI7',
#   'A304R05UY7AAXU',
#   'AHJWTAIN9L2S6',
#   'A1I7T0F7ACJEIF',
#   'A2VBCUX8ASOGUK',
#   'A33RPKXHGZIOHR',
#   'A11T4XTW8J0TI9',
#   'A1O16P5JZHUB0F',
#   'ANGVFO3UHVLRA',
#   'AE6E3SHOJGCJB',
#   'A1M59M6NMKZGAV',
#   'A3R4E31ZLGJ6UI',
#   'A2JCQR1RU3OQD3',
#   'A2TV8S97WQDBE',
#   'A35HTLTORQUI16',
#   'A3K5A511O320W5',
#   'A3R8P5TNCGMLH4',
#   'A1NK2GCYKD4E6C',
#   'A73QB7H0QC8A1',
#   'A1D8KCM2VM67UQ',
#   'AC2CSOQRVC386',
#   'A2CDDCNUR465JA',
#   'A1MRTJ4IRYRP79',
#   'A1WMZ7T83OQYG0',
#   'A5W7J1ADHR0JW',
#   'A1ECE7V6R9ZC86',
#   'A1Y59VESIW3FTX',
#   'A1Y8AR5XK45BCN',
#   'A26X1J4C9TDM3L',
#   'A2B2C33ZD6M29L',
#   'A2F0Z3TX35FY4G',
#   'A1L5VIH91TEICJ',
#   'AGQVVT040M716',
#   'AVCJNJPMRUZDJ',
#   'A1B0Z197A76M5G',
#   'A3S8B7RV1PA5KF',
#   'A33MSICPPOIZYJ',
#   'A2WBYTBNCDPR32',
#   'A2DR4PCGBQTBZY',
#   'A1SYLT4RMTQ0ZP',
#   'A1O0VSHXLYHTWM',
#   'A22GAIUXABEZQZ',
#   'A30THE0OF8QFPX',
#   'AE9DX7OHHOYRN',
#   'AJAR94SZO6MH7',
#   'A3GVYSRHXK6HWC',
#   'A1QQML1LFUS73J',
#   'A19TNVHZUTWYKB',
#   'A122O00K0Y3ET3',
#   'AXU54GJS1H9LH',
#   'A2WZ0E6YG0CW97',
#   'AJ08XMSO3RRLZ',
#   'A3C0TV0YLTIBCD',
#   'A6T3UF3K5IWE3',
#   'A1MQT535KPNSTE',
#   'AYW9AWQ95IP4G',
#   'A2JZ26T3MERXJO',
#   'A19TO0OGR7DTDV',
#   'A1W65LHHSAEHUG',
#   'A18K2AYKW7HYI5',
#   'A114XFQBIBAKOS',
#   'A395JMIYMC0AAY',
#   'A3GAN4X1TF8TPY',
#   'A37SMD2Q6U35P0',
#   'A12QDT4F7J5NHK',
#   'AB1S9DU7QYDY1',
#   'A32R52FEAZFIG6',
#   'AUSDIJBEN8QUR',
#   'A2SP1NV5OMBVBB',
#   'A1B9YA5YGAUS89',
#   'A1DQ372360TL7A',
#   'A24YJL76TNP3T2',
#   'A29AJMUHJUAGKN',
#   'A398N5G346IB20',
#   'A22RM0ERASYZWZ',
#   'A29R4JSTENC6TJ',
#   'A4BS0C9AEFLCH',
#   'A26D07R364UJ3B',
#   'A2D2P3PXKRDVZ8',
#   'A3CRRC791J3CQ',
#   'A3J1HDPAR7U1Q7',
#   'A25NTNX0RLFZD3',
#   'A20N3FGGVHB5BT',
#   'A21RWV6TNM237A',
#   'A35Q1O4V2WHKT8',
#   'A2ES3YL2JZ4UIX',
#   'A1GXXR1MIRDS6O',
#   'A20KEQC3OVYM7I',
#   'A3TG67K2M6PKFM',
#   'A1JW0TIYF8WI61',
#   'A8N68HEWM2T8H',
#   'A3TC7CO24O3ZFT',
#   'A6K21TGNYLBCH',
#   'A3FQWGPAXF0JI9',
#   'A2VXEBPM40L7DT',
#   'AAAAWXZ4P3TS9',
#   'A2S9W038XO3D26',
#   'AGWRDGJYX6OVE',
#   'AEYMYB7GCZ45S',
#   'A1Y1O6SI5H5M5Q',
#   'A2ZUQ8ORB8G03W',
#   'A1SQUR6CY1MD63',
#   'AI6SSY3GZAT2S',
#   'A2FDAYR3JCZRVU',
#   'A2GVVAO242EK1D',
#   'A3F5DIB5CVJAT0',
#   'ASXAR94F36G7A',
#   'A685THCIU84BK',
#   'A2GTV96Y8G2XD1',
#   'A3NJZAAEQPFRG4',
#   'A244Q5XJY4VW4X',
#   'A1V2H21WSS94VO',
#   'A374HZNV66HNH5',
#   'AF6UENX3DXD5H',
#   'A24GEPTW6KZFEO',
#   'A1C2Z3ZJY2Q8RZ',
#   'ALVKWM1FZD2MP',
#   'A13NJC7UY7T3ZK',
#   'ACKIL3XYWCO6P',
#   'A1UUIN9M0042PM',
#   'A2I92DNZE4VEZJ',
#   'A3KWW49IK4MH9T',
#   'AWOVDYT77BUER',
#   'A1CLV3MLALJGQZ',
#   'A17LABDQA4CXH',
#   'A3MBQRISS2KPVI',
#   'A6QYTV6FFDAPY',
#   'A2ACH23JU7KFHD',
#   'A2CNPDOIJB0ZNH',
#   'A3MI6FE0G78BBV',
#   'A22TRQL7W36GJ5',
#   'A1J0Y2HB1L3DSR',
#   'A3POG2EWNYU4DZ',
#   'A3Q34LR5ETF0NV',
#   'AD1358H3YF65O',
#   'A2Z1QHZO13M7L3',
#   'AP34C8ZPXTUQW',
#   'A2KDIZ61EH3FK',
#   'AKX2TQEK7B77M',
#   'A3CYL5EUZTUOUL',
#   'A6LR1UJKXJLR',
#   'A2BFJ9COHFCTX9',
#   'AEFY23IDNXF8E',
#   'A2GZCZJ6XIXWLE',
#   'A1YV04K3XGSLR5',
#   'A2CWUWTUUT4WSJ',
#   'A13T6Z2P1HWL9U',
#   'A2F2H3UPS78AAC',
#   'AWRK58OCTFYX5',
#   'A3EQAF5D9ID1N',
#   'A2844M8MZFPAWR',
#   'A1BY49Q9VZTI2G',
#   'A2YX0UUP8QOG8F',
#   'A3DE797MUUOSYO',
#   'A21E7ITL9P4VIT',
#   'A27XD3ZVH55JXJ',
#   'AUI5SZ3TEVV63',
#   'A23EQ5IQ1YA9GI',
#   'A1JJZBNXDNHNHL',
#   'A3OMTFU440LF2U',
#   'A2ZFH30N3FVLTN',
#   'AUR6L33WK8EDK',
#   'A25EPRTZKGBXWA',
#   'A2BJ5Y7XDJR2GY',
#   'A3NVL7MT3U3CH3',
#   'A145G4ASSP0751',
#   'A267AWW0EJ9NFJ',
#   'A3GDE9L39H5FXE',
#   'A1M916LOX4Q4XU',
#   'ASYPOY2NH6FYB',
#   'A546O6WLFZVX4',
#   'A4K0NNI3ZC4FM',
#   'A35DDHCTBWCFX',
#   'A1X45WRPSN1MKE',
#   'A2G8NV69HRZAC1',
#   'A2B5LJCP7WYYA7',
#   'AMNAQSBHZ9OCY',
#   'A1LUQRA6C4ASLZ',
#   'A3S1LODOMY3TKT',
#   'A1R0PBOIOOIPZK',
#   'A3HG4UBJWR7C1D',
#   'A3O3NXADPDGAJN',
#   'A5EDFXBS2DU3',
#   'A2FJAXVQFHFBBJ',
#   'A2VX365YPHFOHV',
#   'A2FL392QCIJA8K',
#   'A346CC958W2UDP',
#   'A26BR93L5PWX8U',
#   'A20H8RF4I0P7ZM',
#   'A1OSE7LZCBE977',
#   'AYP0N0SLU18ZF',
#   'A2P1LJ710KP8NY',
#   'AHFDMAPYQJ873',
#   'A2NJ7K2V2METAG',
#   'A3JGUI9Y0O2TRB',
#   'A3E2BX5IEX21IZ',
#   'A2H88KG6C885PP',
#   'A19MUPK5SIXT7',
#   'A2ZMGMQ8H5DQ1T',
#   'A2IGUIPG1836ZO',
#   'ARSWYYACB540V',
#   'A3GQRDMGNLYKTA',
#   'AG7GJHFTI50KE',
#   'A3DHJ0IP00NMBJ',
#   'A10VB8LZU3G0TA',
#   'A1QE3GF6GC0U8N',
#   'A2K0ZKQKZ78JCM',
#   'A21TH7QLMDOMRN',
#   'A3QQDCOUBQCK6O',
#   'AYY419976OEFA',
#   'A5QZ9BJRY0J1I',
#   'A1KZANWS74LERT',
#   'A9BOFH0OGRWUL',
#   'A9H7U8Y88VWF2',
#   'ABJS0HSU1RWLJ',
#   'A1PDIALPRCHBCU',
#   'A1HWJNCTQO16KH',
#   'A2T0GWSZFLUZE3',
#   'ABALXU1HA4TNT',
#   'A3KWP14YVHGO20',
#   'AKE8JMTCUVMQ3',
#   'A265V6ZWEKJC6P',
#   'A263HVFAPMCR3M',
#   'A1SHQU1EL5Z4RR',
#   'A2XJ4KGMBZM8XA',
#   'A3JBJXO0YEFNET',
#   'A27XRJGNCDA2IL',
#   'AF8OHFKKUBOTE',
#   'A239P8PO0NEU0Y',
#   'A3IO9HYBUNKLDR',
#   'A1G9PVNH39CKTK',
#   'AE89JVMI8GSQB',
#   'A1ZMIYE7TY1V07',
#   'A3A1ZWZIIZZ416',
#   'A3VW61U4HDZTN5',
#   'A39PWEH4O0MWIB',
#   'A1ER8FS19S0XY5',
#   'A3SV8R082H7DA1',
#   'AHMHFB7ZAQMYH',
#   'A2DW5GIXY5TKQS',
#   'A1W6GMETQVRGVQ',
#   'A39SWBFBKM703F',
#   'A3RWJ9U5QBF7P7',
#   'A3NCIN6TNL0MGA',
#   'A1OV0JETL5K1HD',
#   'AC37KL00UBBA8',
#   'A13W688MLCFVDP',
#   'AKMJ3AC42ZQSO',
#   'APUEXKPAJCPRI',
#   'AGBWGGUMLG4T9',
#   'A37BVM0O7RSIIR',
#   'A1JAP7PWENPG40',
#   'AGV9995OJHQE3',
#   'A2SUTZRQY7DOIN',
#   'A1XAJOJ9H80OD6',
#   'A2MM0LK6S7JKN1',
#   'A2F48KZMFM68QH',
#   'A3DKLB28IVPI21',
#   'A8EQKQ6BUEUC3',
#   'AB9DH5FFJGG4O',
#   'A1JF9RQPQC6V00',
#   'A4FJT3F0WNAK6',
#   'A3K545E3YPHON3',
#   'A2T634M752XYRL',
#   'A10YG7GOS3VDR1',
#   'A2LM7QTO3NRBOC',
#   'A3CJ7QXMJWU3KS',
#   'A2AIOMUDMQQ00A',
#   'A361JGEVAIRK8P',
#   'ACRL9A07IOSB5',
#   'A171C8MAMX64H2',
#   'A2S6W049LDDFWI',
#   'A2UERM19FZPVLO',
#   'A2KF9C81HER17Y',
#   'A2Q55OOMM7SUNL',
#   'A1AO6I6CY1FLWQ',
#   'AMX9W1NC83SD1',
#   'A2OIR0M1W38DVL',
#   'A1EVGH0DSBOF1P',
#   'A17HPF2ZLS10GO',
#   'AKNM21WPILUYE',
#   'A1BJPYCYTB36B2',
#   'A342IS5JEYAHSV',
#   'A3NEQ76S2YYE7T',
#   'AWZ3K89ZLXPTD',
#   'A2GSLAP1JEWKZ2',
#   'A35VQUG0DYVBOM',
#   'A2PVQSNK8SUXCJ',
#   'A3TMMOZXAOGJAC',
#   'A3785G094AV00Y',
#   'A2U3TMV5J60KV2',
#   'A3MEAPABM2ELTW',
#   'A2U05GMOXRQ05Z',
#   'A10OW3BQUCV5S1',
#   'A2FV2GEWZA0MTY',
#   'A2G6H3ATIN7581',
#   'ACUAIHA1AJMJJ',
#   'A23RPQN1SBZLC4',
#   'A38Q46WBX77Q0K',
#   'ABL5SZSO8CWMR',
#   'AWKYEOO12RWB1',
#   'A1OFLNZH47TO0N',
#   'A3QJKSEMQ38ZMF',
#   'A309S6LB8SWVRU',
#   'A2PENTK0T0LBDE',
#   'ANR27QFPDWVQU',
#   'A2KW6HTAB954HX',
#   'A29EA65UPWLDII',
#   'A26NFA8V2LC6J8',
#   'AB7EU8PZRGLID',
#   'A26GI2CX15IIIP',
#   'A13FFU5D0LSHXZ',
#   'A15JIXSYJJATHJ',
#   'A2UV18FE04RY9W',
#   'A1F7OAJS8N6BL9',
#   'A27X79TNTM64WB',
#   'A1P9D2568DB4Y0',
#   'A19CZX2AUG5PP',
#   'A2ZYTIY6AMWFRA',
#   'A3KENV3PZNHXP9',
#   'AMMFCXYDOWG98',
#   'AVQ1BSTHC5KY7',
#   'A1FB7V0JQ3E38G',
#   'A1K567JNM89190',
#   'A2F699JP9845U6',
#   'A34238T9RH145F',
#   'A17JUP3QP9CXDW',
#   'A14DC21S0DCC3A',
#   'A2YZGUP8BMRM8R',
#   'A3VU14NS9NPZBB',
#   'A3S7B6JGFHH5A8',
#   'A3P8ATPVP1WQUZ',
#   'A3H6GX0XC06B6V',
#   'A1XYJV7Z3BZYCM',
#   'A112994DD5BRZK',
#   'A3LPPUCGWCWJUL',
#   'A1MUVZZESGCAPC',
#   'A2XCUW7PE4QC1',
#   'AOC3BOLRQVTC7',
#   'A3TD5LVI3L2GRS',
#   'A3EJ2ZVRWFTLW5',
#   'A1DWJH2QI24P91',
#   'A1YEG2AEYGVX5W',
#   'ARLCO0PRD9EE8',
#   'AMR5YT6GAIZZS',
#   'A1LDBBRYNO514C',
#   'A117T47EUW6FTT',
#   'A13ZX4W0M0WSJX',
#   'A2BYA32WOLE7IJ',
#   'A1Q4TWLDK0OAGK',
#   'A13SBIR1G1QWU5',
#   'ALREPHCQPXYID',
#   'AETENK85RU3IG',
#   'A1V46VHNI19FSW',
#   'A160DZI0SS1HKE',
#   'A7T41MNOJLKKF',
#   'A2D1T47LSFE4BU',
#   'A20RQH3NBXZ5NX',
#   'A2521999L4AH6M',
#   'A20ZELKBSRSE5U',
#   'A3L05ROQS9KBUD',
#   'ABVPXZS221ZZX',
#   'A3SUT1MAZM64Y5',
#   'A2N2SAMNJFKEMC',
#   'A1B4KQ3R7WVQHE',
#   'A3AU7YI0VHOLK7',
#   'A1ZDQMJP7VGD2L',
#   'A1ZDUJ418V8MJF',
#   'A1OE0G4PBFQF9O',
#   'A1OJQGIBLAK9SE',
#   'AI0IA3DQLXZV7',
#   'AEGINM4M3KYTS',
#   'A7CUB67DWUO6Z',
#   'A2RKKF4CQL6ZGI',
#   'A25Z8XZD4TT867',
#   'A28ZQFSYTJM5QU',
#   'A144E3XPIRMD9G',
#   'A2DYFV80KTK7S',
#   'A2NN1Y5EYPW3GZ',
#   'A3FE1GMRNYR3M9',
#   'AD45Y61O9G8YW',
#   'A1LR7Y4RVC9DAX',
#   'A14MBLCVPOSDTW',
#   'A23L2IJ9HIZ0YO',
#   'AQGTXREXIGQNA',
#   'A3BZTIHXNM4MIW',
#   'A7FC7IASB33OY',
#   'A2JC3NNXBTY45E',
#   'A37RBD1X8PNVNH',
#   'A9J6JWBSO8JQD',
#   'A2XA58R0QA4VZ4',
#   'A1AWWVITJKGQIR',
#   'AWW65D6CF5JN',
#   'A3LAZCMCDRAHHU',
#   'A3HHEO6BTCYAZ2',
#   'A352SLKU8B8T95',
#   'AGDK15O1WX2GV',
#   'A1WDLSO45AZRL3',
#   'A24E4W6ULTZXC4',
#   'AS30PW8XDONXZ',
#   'A3R049R1TFAQO6',
#   'A2MNI6SSEVRFCS',
#   'A9RDF46WKWE3F',
#   'A1SQNDPVVC9NXO',
#   'AIB3DS3WAWTRD',
#   'A3G9QKJV718L9K',
#   'A1EGD35EOL46LJ',
#   'AHIJWTOEGN2GT',
#   'A3NRS0LYAJ4OD',
#   'A3VOFA6C01UX9O',
#   'A2JU7KIB8M33D8',
#   'A1T4QQGWVM9F65',
#   'A1D0EXKZUXKQXF',
#   'A3Q02GRVYODVS0',
#   'A23LMLNK7CB578',
#   'A1Z3JY8W8ZWYIW',
#   'A9I34WK4MI9XT',
#   'A3AOR1Z4XNT61',
#   'ANG6JLS9QGZH1',
#   'A12W3YO58YMVPN',
#   'A13J8ECWLGIHYY',
#   'A3JRVTGYT7H184',
#   'A344DHPTQ3LHP',
#   'A25T5MUU6VKNW1',
#   'A3NDNHHQ2PD9GT',
#   'A36K84HIOJ2M7H',
#   'A1IRGF5TSEFQTQ',
#   'A3PAPX2V6CWW18',
#   'A1JRFMQJPNTTWT',
#   'ATHGLCQMGBQC6',
#   'A3AKYOQOLU50GP',
#   'A212DA6C81T0P7',
#   'A1A3D4BWZECTG6',
#   'A2T6JKCIPMHYLT',
#   'A1UE2SCQCOTNYQ',
#   'A12CR5V3TOE1CQ',
#   'A1OCG34T0WSUBM',
#   'AVANQRRL5IZ2W',
#   'A6YPTACQO630R',
#   'A3TQJ5AQXW6CZH',
#   'A1IXSLMDYWJ98E',
#   'A3LPILOMRCV2UB',
#   'A3A9Z2VGL17RZF',
#   'AVVIFHWQ8VIVB',
#   'AC9MB4QCYU1OW',
#   'A3ANOCCKX7GJQD',
#   'A10GVFRXOU50EG',
#   'A3MP6UL203H58J',
#   'AIO3AYDKZZR2O',
#   'A2Q4HQ6NEHTEFW',
#   'A1ND40CVUY9EGV',
#   'A1XEJB3QD10IXW',
#   'AB0I5K1QGSTVF',
#   'A3JFST3X09DYOT',
#   'AM0K3IRH9THID',
#   'A3BD1QFSIW0DS9',
#   'AXVB9GSWYGD6H',
#   'A3TLSSTMZS1MEK',
#   'A6LK0N2REYVHV',
#   'A2J07IOKLOVMZD',
#   'A1FHJ15665ICAU',
#   'A1GZP30JDRTO4B',
#   'A32H3YLYCRTG1E',
#   'A1ARRTN4SSKFQC',
#   'AU7IWBDJPR17M',
#   'A1ZZO5S1NQAD6V',
#   'A5T9UDYEB3KI2',
#   'A5OO87OWPJX7T',
#   'AW63QH17C95I7',
#   'A3U4FCEAT75XLS',
#   'A2MM4U2HHM7VQS',
#   'AX56IM3N2URA3',
#   'A3JRF21TP8FLUY',
#   'A2Q3RSFWJJJGFU',
#   'A20QI5C2MFOXD4',
#   'A2CU3X1KLYHQVM',
#   'A2YWTWJKLSDT2B',
#   'A341QOMZ1KK5UZ',
#   'AP862F6T969GA',
#   'A2ECWEVUVY3TLD',
#   'A10ETL026O72SD',
#   'A3TLVFC5BYBKWL',
#   'A1XU8O3PVY2BMJ',
#   'A3X89NSW91SQK',
#   'A3DKACN7Z0XKP8',
#   'A1RDHX6H8BSYB6',
#   'A35Y42X3QEBZBF',
#   'A3H1VMLQRSWGS8',
#   'A138GKGY17L0GF',
#   'A244MKQBMUB616',
#   'AWRSH1K12X9OB',
#   'A21C56XT3U187Y',
#   'A2GTL190AKLIN5',
#   'A13SRVF5NDX5HS',
#   'AW2BCFZH1JFAE',
#   'A36NBWGUWLC5H3',
#   'A3TFLS30TDHN71',
#   'A26NHTUHAUG8EL',
#   'A3TVBMZDWQ49X9',
#   'ARTZD49FD70P0',
#   'AKZBWCGZ2SGRU',
#   'A1U7YD2UFIDBI4',
#   'A3RW9R1E9BV8PA',
#   'A22X7SIDJG46KU',
#   'ANN2E04ZJB9ZM',
#   'A3PJ0CZVH6VJ8P',
#   'AYWDNGIAJ7PCZ',
#   'A3NT82XOMQO0HM',
#   'A1QF9UJAOTB5H1',
#   'A16MR7M3R1RLR7',
#   'A24X22O5HEVN6M',
#   'A2NAJSL0F7Z2XQ',
#   'A2J63IBWUEHCFE',
#   'A3R00HLXQM36PC',
#   'A2GDRGIPL42XEH',
#   'A1FSIIG5WQ3OJU',
#   'A3HR8LWANZ4PY9',
#   'A2CVX1VF4BVR6F',
#   'A2GV43PVC5CDSO',
#   'ATRHUZMP1ZXGR',
#   'A189SZYB0HDQWZ',
#   'AJDF3AC49T65B',
#   'A17K7I5WWOIXXA',
#   'A23QYAS9Z5TQS6',
#   'A2GJJIBH8483SP',
#   'A2OB8PEZRD7NTK',
#   'A1CKORG3R6OCHE',
#   'A2ICTGERAVLWG6',
#   'A1X0C69XHXE5LU',
#   'AU4EQ4DZYOGBS',
#   'A2M0YOTXV1XE1R',
#   'A1S1T08VFGMBJ7',
#   'A8YYDAZXF16R0',
#   'A3F0G9DB81UFT1',
#   'A2P0JBIVA5QB2B',
#   'ARKFHZQ717HJQ',
#   'A2KDPQAY583G5T',
#   'A1DU128WE2R6ID',
#   'A3GOUCF56NLKXG',
#   'ADJBH7WWIRBNV',
#   'A3G6IB4XPW1U9O',
#   'A1CH6TMQLXP9D2',
#   'AGMFIOFXP167Q',
#   'A149GMT1XX44UD',
#   'A294V02KPUFIQT',
#   'A16XEVSNW9CGDA',
#   'A3BA7LK9S6TZVI',
#   'A37V1DDID833JZ',
#   'A1D6COK1ZEGGIV',
#   'A2IMAUDU233CS6',
#   'A3MRTI6AV8OY4I',
#   'A2A29TKIYGC5SJ',
#   'A16KPQPPSZPX7M',
#   'AJOD3G0X4C18B',
#   'A2B8IZK6BXIJEU',
#   'AXXJ1LHG4Y41C',
#   'A2D90GI54ZENBS',
#   'A3P5M8NU3L560H',
#   'A2EAO6W0FFIQPR',
#   'A3US5DG8UOLJCE',
#   'A36VXIM30OVGCL',
#   'A2QLSHQ801U9B3',
#   'AX633RQS2HE61',
#   'AKCGXR9VHFQV3',
#   'A3JBK9T7ULS8J9',
#   'AJE0J1DPEOKAD',
#   'A3HH5IS95FDORA',
#   'A3AG7NYTZTWK3J',
#   'A3UM7B7E2QKYRC',
#   'A4RSTQGKXYRGB',
#   'A3BBD5HING8X5N',
#   'A23ZEOLUYSH9QO',
#   'A170UF2CVBGG63',
#   'A1NOQAHZ39TWNW',
#   'A2IF8IPI2ALJXC',
#   'A1GPZNZF47UGFH',
#   'A2WGQ61ELN9NNT',
#   'AXD0MKZHXZ62M',
#   'A2EC1TDVFRBZ5Z',
#   'AO6BDVZZ74LO2',
#   'A265UYLB7QTGDA',
#   'A3BIFWZFFD0Y6Q',
#   'A35VWEPE83EAME',
#   'A2NTOYEMIIQJQ9',
#   'A3RHO1FVG2YZWT',
#   'A7SPR97HRZ9K1',
#   'A15YJXDPCPDP0G',
#   'AD18NL069X7XY',
#   'A14S1NTLJK4CER',
#   'A1T3A5QJW73HIB',
#   'A2K9W4E1UDAETC',
#   'A1IFKCW7EKQ8OZ',
#   'A290XR33DQ0P9I',
#   'AA4YU1Q8YVBXA',
#   'A2SAOOVMKJZNY1',
#   'A20MN8I20E4I5V',
#   'A2OEJD1B7VVI7C',
#   'ATGJDGZA5LQO3',
#   'A6R9P5F5CJVCP',
#   'A3CSV5C2G3Q4LQ',
#   'A1G2K095PXF162',
#   'A3LKI604GLT3WQ',
#   'ALSANQPACR0GS',
#   'A1LNNM1C27893D',
#   'A3V6AYYI6K9CAG',
#   'ATZF5Z4Y1AS7T',
#   'A2EK17TRP7FNSJ',
#   'A5SP2XK88XYRM',
#   'A2LLTL22G9WFNQ',
#   'A1OCAVJFX5NE6R',
#   'A32KNZ0ELCL6A7',
#   'A25EKBAN8BSMKR',
#   'AIBZYH7KI1AF6',
#   'A2MH02RR117O6N',
#   'A3DCI5K2FELKQT',
#   'A2TRKPODNHBKQA',
#   'AU7618IMRJN93',
#   'A1FTT3TA4TE2ZO',
#   'A2JIFUCJTPJTRK',
#   'A47I87R36GTFH',
#   'A1SG1DJ72ISCRU',
#   'A3V3F1GPP5GO7A',
#   'A3FPSOE0FA0Q3F',
#   'A2NC6AS6Z4B46G',
#   'AXQKNGDI2SUKI',
#   'ALLWQ4D9XQUUJ',
#   'AZ6DK4KG87ETR',
#   'A2QWRF2T7XRM7U',
#   'A4ZW1B862O9PM',
#   'A24NQKZJJELGTT',
#   'AI13JCP2H94M6',
#   'A11U3T8WDRJX6Z',
#   'A3QCDNW0CDD0VM',
#   'A367BHPUHCNIFJ',
#   'A3QZYDMLXNMMXP',
#   'AHQ8MN8ODSQQ2',
#   'ANL0D4ZPFOXGY',
#   'A34LUB01TWP5W0',
#   'AGJW049PFHN7K',
#   'A27QWOVMDM23SZ',
#   'A1J8WE6VV0R1FX',
#   'A27S8LDHWPZNXY',
#   'A12GCHR5DAW5FH',
#   'A1JQYSKYVKAZNG',
#   'A26DR7AX38KTQ6',
#   'A1HMZLHOLMTMOP',
#   'A4G6PXT6A5V38',
#   'A2I57Z2PBIUHL5',
#   'A1S9LYLPUZC2UI',
#   'A2KZRF9CYWPM4F',
#   'AVKLSFC7NX1E7',
#   'A2WPAH5L81OPWD',
#   'A1YHMT20F44P5W',
#   'ASPE69S097H6K',
#   'A3EAK892U9OZLP',
#   'A68T73K2JRT2Y',
#   'A1CU8DAC77BINV',
#   'A2YLLW5SDPK1RX',
#   'AT8H39DJZQX07',
#   'AFVSSLIL2Y2HR',
#   'ASHAT425I9IA6',
#   'A3QA4MWT14T6R9',
#   'A3K7SES42TY5PP',
#   'A3L2552AXL8HQR',
#   'A16AEF0IDVCTE1',
#   'A2YWUFHZSOMVBL',
#   'A2JVUP71C1GYZM',
#   'A3TV830HHADNOW',
#   'A5Z2A40FIADA8',
#   'A3I7VT0VWVDR13',
#   'A7LU0BVGFS1BR',
#   'A1KOQZUSL20NVF',
#   'A1EE1SNY2JP6AX',
#   'A2J9VN2REHLVJY',
#   'A3NVZ5ZNIHPX82',
#   'AWANM93TH3Y8T',
#   'A3DY8BIY32G4BD',
#   'A2HAZ99DIO8HPU',
#   'A20IJTKI75QKX0',
#   'A9NAYVEYF695W',
#   'A2HOXVM3GHZPGZ',
#   'A29N6V740F8JBK',
#   'A3JH009JCH4NNB',
#   'A2V1ZQX4JAZLG5',
#   'A3EP37WC9CK21J',
#   'ACAFCXHBMPWJ',
#   'A1DNPVSSN6KLUG',
#   'A1PPIW852MAHWO',
#   'A1LUG5WY9JKN3O',
#   'A20XH5W9HSCALE',
#   'A245TPVSV1S17Z',
#   'A30WERRQA7L2J9',
#   'A3P3TGUII2W6H2',
#   'AWIU9NJ70T9R3',
#   'A25HISNEZ5KEUE',
#   'A1J6W8KAV3UOQ6',
#   'AE28AUOA6RRME',
#   'ANYIKCZ28PVLM',
#   'A1FM3J5W3ERFZ4',
#   'AG2IR1C0MY57T',
#   'A7RH4K0X3AHNE',
#   'A372JXFNS3VSUI',
#   'A36VJLPORRAWN5',
#   'A1SGWAMAAMWE0O',
#   'A3QLQJUHVBOB7K',
#   'ASSVFV2YA78D5',
#   'A2348Y9GX6RP8G',
#   'A4HDYJ2XW2KET',
#   'ADLES13EWWXSH',
#   'A29N84FQ3CPCGV',
#   'A288DKPY1D257T',
#   'A3Q5JTDDZAX1AS',
#   'A3B39J35AE1B2D',
# ...
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 86-pc'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 38 oz'},
#   {'Size:': ' 2 Pack'},
#   {'Size:': ' 6.25 Inches'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Format:': ' Health and Beauty'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' package of 4'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 17 Peice'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' package of 4'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' Charcoal'},
#   {'Size:': ' 17 Peice'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   '',
#   {'Size:': ' 13026ffa'},
#   {'Size:': ' 08d1af09'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' Purple/Black'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   '',
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   {'Size:': ' 6.25 Inches'},
#   ...],
#  'image': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/7188WL9FM5L._SY88.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/71LTtXSjChL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/717GsQ2qZGL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71j6zjqJQCL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/715ulS60nRL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/81-K8uS92IL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/61PvvFCEujL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71jr8uX44RL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71aS0VElNgL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/81TLgmxb-0L._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/713i37-a99L._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71FRQVZErjL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71E1fbVC7wL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/51MJJF-ySWL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/81Tia7nE8EL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/61DW1A6E1fL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71Gx3R-JRnL._SY88.jpg'],
#   ['https://images-na.ssl-images-amazon.com/images/I/41eW6YAavSL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/61ZHNKFp2QL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/61JAjVED7tL._SY88.jpg'],
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/81oE26mQ6pL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71KI86krQEL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71Ckd1JImFL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/61CcwBnyytL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71dYdZacQ3L._SY88.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/71uv0xi32tL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71X4k4rJZZL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/617SzihcYgL._SY88.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/71hwbsUn8oL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/31KB7HptxBL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ['https://images-na.ssl-images-amazon.com/images/I/71NS9NbbyaL._SY88.jpg'],
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ...]}

# %%
df = pd.DataFrame(pre_json_data)
df
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           1.0      True  02 19, 2015  A1V6B6TNIC10QE  0143026860
# 1           4.0      True  12 18, 2014  A2F5GHSXFQ0W6J  0143026860
# 2           4.0      True  08 10, 2014  A1572GUYS7DGSR  0143026860
# 3           5.0      True  03 11, 2013   A1PSGLFK1NSVO  0143026860
# 4           5.0      True  12 25, 2011   A6IKXKZMTKGSC  0143026860
# ...         ...       ...          ...             ...         ...
# 371340      1.0      True  07 20, 2017  A202DCI7TV1022  B01HJEGTYK
# 371341      5.0      True  03 16, 2017  A3FSOR5IJOFIBE  B01HJEGTYK
# 371342      5.0      True   03 1, 2017  A1B5DK6CTP2P24  B01HJEGTYK
# 371343      2.0      True  02 21, 2017  A23OUYS5IRMJS9  B01HJEGTYK
# 371344      2.0      True  12 15, 2016  A24KQ9RVU81L87  B01HJEGTYK
#
#              reviewerName                                         reviewText  \
# 0       theodore j bigham                                              great
# 1            Mary K. Byke  My  husband wanted to reading about the Negro ...
# 2                 David G  This book was very informative, covering all a...
# 3                    TamB  I am already a baseball fan and knew a bit abo...
# 4              shoecanary  This was a good story of the Black leagues. I ...
# ...                   ...                                                ...
# 371340                Sam  It was awful. It was super frizzy and I tried ...
# 371341                TYW  I was skeptical about buying this.  Worried it...
# 371342     Norma Jennings                           Makes me look good fast.
# 371343                Lee  Way lighter than photo\nNot mix blend of color...
# 371344          Season341  No return instructions/phone # in packaging.  ...
#
#                                                   summary  unixReviewTime  \
# 0                                                One Star      1424304000
# 1       ... to reading about the Negro Baseball and th...      1418860800
# 2                                          Worth the Read      1407628800
# 3                                               Good Read      1362960000
# 4                     More than facts, a good story read!      1324771200
# ...                                                   ...             ...
# 371340  It was super frizzy and I tried to comb it and...      1500508800
# 371341                                            Awesome      1489622400
# 371342                                         Five Stars      1488326400
# 371343            Ok but color way off and volume as well      1487635200
# 371344         Might return for a replacement if I could.      1481760000
#
#        vote style image
# 0
# 1
# 2
# 3
# 4         5
# ...     ...   ...   ...
# 371340
# 371341   34
# 371342   46
# 371343
# 371344
#
# [371345 rows x 12 columns]

# %%
try: 
    trying =     pre_json_data['overalls'] 
except: 
    trying =     'bingo'
    
print(trying)
# Out:
# bingo

# %%
import csv
data = open("C:\\Users\\andre\\Downloads\\All_Beauty.json")
#open file with raw text reader
#for each line remove leading"{" and trailing "}"

data
# Out:
# <_io.TextIOWrapper name='C:\\Users\\andre\\Downloads\\All_Beauty.json' mode='r' encoding='cp1252'>

# %%
foo
# Out:
# '{"overall": 1.0, "vote": "3", "verified": true, "reviewTime": "11 19, 2016", "reviewerID": "AMACNEW14ADMX", "asin": "014789302X", "reviewerName": "rabiyaa123", "reviewText": "it burns your eyes when u put it on  and very light so u have to keep going back n forth a lot to get the dark eyeliner color.\nalso it smudges lot. waste of money.", "summary": "i do not recommend.", "unixReviewTime": 1479513600}\n'

# %%
foo = """{"overall": 1.0, "vote": "3", "verified": true, "reviewTime": "11 19, 2016", "reviewerID": "AMACNEW14ADMX", "asin": "014789302X", "reviewerName": "rabiyaa123", "reviewText": "it burns your eyes when u put it on  and very light so u have to keep going back n forth a lot to get the dark eyeliner color.\nalso it smudges lot. waste of money.", "summary": "i do not recommend.", "unixReviewTime": 1479513600}
"""

# %%
type(json.loads(foo.replace("\n","")))
# Out:
# dict

# %%
df2 = pd.read_json("C:\\Users\\andre\\Downloads\\All_Beauty.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e99ab00bf575> in <module>
# ----> 1 df2 = pd.read_json("C:\\Users\\andre\\Downloads\\All_Beauty.json")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1117         if orient == "columns":
#    1118             self.obj = DataFrame(
# -> 1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#    1121         elif orient == "split":
#
# ValueError: Trailing data

# %%
json_data=open("C:\\Users\\andre\\Downloads\\All_Beauty.json").read()
json_obj = json.loads(json_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-40-cbb9bf4b82db> in <module>
#       1 json_data=open("C:\\Users\\andre\\Downloads\\All_Beauty.json").read()
# ----> 2 json_obj = json.loads(json_data)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     338         end = _w(s, end).end()
#     339         if end != len(s):
# --> 340             raise JSONDecodeError("Extra data", s, end)
#     341         return obj
#     342
#
# JSONDecodeError: Extra data: line 2 column 1 (char 231)
